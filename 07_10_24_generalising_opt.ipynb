# %% [markdown]
# <a href="https://colab.research.google.com/github/danieldalton13/optimisation_top_Y1/blob/main/07_10_24_generalising_opt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Working code from 04/10/24

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.colors import LinearSegmentedColormap
import random
import copy

# ------------------------- Configuration -------------------------

USE_SEED = False  # Set to False to disable fixed random seed

# New Configuration Options
SPECIFY_FIXED_MEMBERS = True  # Set to True to specify fixed members manually
SPECIFIED_FIXED_MEMBER_IDS = [15, 4, 33, 34, 41, 42]  # List of member IDs to fix

# ------------------------- Part 1: Truss Definition -------------------------

class Truss:
    def __init__(self, columns=7, rows=3, load_magnitude=10):
        self.columns = columns
        self.rows = rows
        self.load_magnitude = load_magnitude
        self.nodes = {}
        self.members = {}
        self.support_reactions = {
            'R15x': None,   # Reaction at Node 15 in x-direction
            'R15y': None,   # Reaction at Node 15 in y-direction
            'R21x': None,   # Reaction at Node 21 in x-direction
            'R21y': None    # Reaction at Node 21 in y-direction
        }
        self.fixed_member_ids = []  # To be set dynamically based on degree of indeterminacy
        self.degree_of_indeterminacy = 0
        self.direction_cosines_cache = {}
        self.initialize_truss()

    def initialize_truss(self):
        self.define_nodes()
        self.define_members()
        self.define_external_loads()
        self.compute_degree_of_indeterminacy()

    def define_nodes(self):
        node_id = 1
        for y in range(self.rows - 1, -1, -1):  # y=2 (top) to y=0 (bottom)
            for x in range(self.columns):       # x=0 to x=6
                self.nodes[node_id] = (x, y)
                node_id += 1

    def add_member(self, start, end):
        if start not in self.nodes or end not in self.nodes:
            print(f"Skipping member ({start}, {end}) - Invalid node number.")
            return
        # Avoid duplicate members (e.g., (1,2) and (2,1))
        if not any(
            (start == existing_start and end == existing_end) or
            (start == existing_end and end == existing_start)
            for existing_start, existing_end in self.members.values()
        ):
            self.members[len(self.members) + 1] = (start, end)

    def define_members(self):
        # Add horizontal members for each row
        for row in range(self.rows):
            start_node = 1 + row * self.columns
            for i in range(start_node, start_node + self.columns - 1):
                self.add_member(i, i + 1)

        # Add vertical members for each column
        for col in range(1, self.columns + 1):
            top_node = col
            middle_node = col + self.columns
            bottom_node = col + 2 * self.columns
            self.add_member(top_node, middle_node)
            self.add_member(middle_node, bottom_node)

        # Add diagonal members at specified middle nodes
        middle_nodes = [9, 11, 13]
        directions = [(-1, 1), (1, 1), (-1, -1), (1, -1)]
        for node in middle_nodes:
            x, y = self.nodes[node]
            for dx, dy in directions:
                diag_x, diag_y = x + dx, y + dy
                diag_node = self.find_node(diag_x, diag_y)
                if diag_node:
                    self.add_member(node, diag_node)

    def find_node(self, x, y):
        for nid, coord in self.nodes.items():
            if coord == (x, y):
                return nid
        return None

    def define_external_loads(self):
        # Evenly distributed downward loads on top nodes (Nodes 1 to 7)
        self.external_loads = {node: (0, -self.load_magnitude) for node in range(1, self.columns + 1)}

    def compute_degree_of_indeterminacy(self):
        num_reactions = len(self.support_reactions)
        num_members = len(self.members)
        num_nodes = len(self.nodes)
        self.degree_of_indeterminacy = num_members + num_reactions - 2 * num_nodes

    def direction_cosines(self, start, end):
        key = tuple(sorted((start, end)))
        if key in self.direction_cosines_cache:
            return self.direction_cosines_cache[key]
        x1, y1 = self.nodes[start]
        x2, y2 = self.nodes[end]
        delta_x = x2 - x1
        delta_y = y2 - y1
        length = np.sqrt(delta_x**2 + delta_y**2)
        if length == 0:
            raise ValueError(f"Zero length member between nodes {start} and {end}.")
        cos_theta = delta_x / length
        sin_theta = delta_y / length
        self.direction_cosines_cache[key] = (cos_theta, sin_theta)
        return cos_theta, sin_theta

# ------------------------- Part 2: Genetic Algorithm for Minimum Truss Volume -------------------------

class GeneticAlgorithmOptimizer:
    def __init__(self, truss, seed_fixed_member_ids, seed_fixed_forces,
                 material_stress=1, population_size=200, generations=200,
                 tournament_size=3, crossover_rate=0.8, mutation_rate=0.5, mutation_amount=10, elitism=True):
        self.truss = truss
        self.seed_fixed_member_ids = seed_fixed_member_ids
        self.seed_fixed_forces = seed_fixed_forces
        self.material_stress = material_stress

        # Genetic Algorithm Parameters
        self.POPULATION_SIZE = population_size
        self.GENERATIONS = generations
        self.TOURNAMENT_SIZE = tournament_size
        self.CROSSOVER_RATE = crossover_rate
        self.MUTATION_RATE = mutation_rate
        self.MUTATION_AMOUNT = mutation_amount
        self.elitism = elitism

        # Define gene bounds (0 to 50)
        self.gene_bounds = [(-50, 50) for _ in self.seed_fixed_forces]

        # Create mappings
        self.fixed_member_indices = [m - 1 for m in self.seed_fixed_member_ids]
        self.unknown_member_indices = [
            i for i in range(len(truss.members)) if i not in self.fixed_member_indices
        ]
        self.num_reactions = len(truss.support_reactions)
        self.num_members = len(truss.members)
        self.num_unknowns_ga = len(self.unknown_member_indices) + self.num_reactions

        # Mapping from member index to unknown index
        self.member_index_to_unknown = {
            i: idx for idx, i in enumerate(self.unknown_member_indices)
        }

        # Mapping for reaction indices
        self.reaction_indices = {}
        for idx, reaction in enumerate(self.truss.support_reactions):
            self.reaction_indices[reaction] = len(self.unknown_member_indices) + idx

    def initialize_population(self):
        population = []
        for _ in range(self.POPULATION_SIZE):
            individual = [
                random.uniform(low, high) for (low, high) in self.gene_bounds
            ]
            population.append(individual)
        return population

    def compute_total_volume(self, current_fixed_member_forces):
        A_ga, B_ga = self.setup_equilibrium(current_fixed_member_forces)
        try:
            F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
            equilibrium_satisfied_ga = True
        except np.linalg.LinAlgError:
            F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)
            equilibrium_satisfied_ga = False

        # Check equilibrium
        B_calculated = np.dot(A_ga, F_unknowns_ga)
        difference = B_calculated - B_ga
        tolerance = 1e-5  # Adjust tolerance as needed
        if np.any(np.abs(difference) > tolerance):
            # Equilibrium not satisfied, return a large fitness value
            return 1e10  # Large penalty
        else:
            # Reconstruct full member forces
            F_full_ga = np.zeros(self.num_members)
            for member_index in self.unknown_member_indices:
                unknown_idx = self.member_index_to_unknown[member_index]
                F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
            for i, m_id in enumerate(self.seed_fixed_member_ids):
                F_full_ga[m_id - 1] = current_fixed_member_forces[m_id]

            # Calculate total volume
            total_volume = 0.0
            for m_id, (start, end) in self.truss.members.items():
                x1, y1 = self.truss.nodes[start]
                x2, y2 = self.truss.nodes[end]
                length = np.sqrt((x2 - x1)**2 + (y2 - y1)**2)
                force_magnitude = abs(F_full_ga[m_id - 1])
                cross_sectional_area = force_magnitude / self.material_stress
                volume = cross_sectional_area * length
                total_volume += volume

            return total_volume

    def setup_equilibrium(self, current_fixed_member_forces):
        num_members = self.num_members
        num_reactions = self.num_reactions
        num_nodes = len(self.truss.nodes)
        equations_per_node = 2
        total_equations = num_nodes * equations_per_node
        total_unknowns = self.num_unknowns_ga

        A_ga = np.zeros((total_equations, total_unknowns))
        B_ga = np.zeros(total_equations)

        # Map reactions to indices
        reaction_indices = self.reaction_indices

        for node in self.truss.nodes:
            eq_x = (node - 1) * 2
            eq_y = eq_x + 1

            # Assign external loads
            load = self.truss.external_loads.get(node, (0, 0))
            B_ga[eq_x] += load[0]
            B_ga[eq_y] += load[1]

            # Iterate through connected members
            for m_id, (start, end) in self.truss.members.items():
                member_index = m_id - 1
                if node == start or node == end:
                    other = end if node == start else start
                    cos_theta, sin_theta = self.truss.direction_cosines(node, other)
                    coef_x = cos_theta if node == start else -cos_theta
                    coef_y = sin_theta if node == start else -sin_theta

                    if m_id in current_fixed_member_forces:
                        fixed_force = current_fixed_member_forces[m_id]
                        B_ga[eq_x] -= coef_x * fixed_force
                        B_ga[eq_y] -= coef_y * fixed_force
                    else:
                        if member_index in self.member_index_to_unknown:
                            unknown_idx = self.member_index_to_unknown[member_index]
                            A_ga[eq_x, unknown_idx] += coef_x
                            A_ga[eq_y, unknown_idx] += coef_y

            # Assign support reactions
            if node == 15:
                A_ga[eq_x, reaction_indices['R15x']] -= 1   # R15x
                A_ga[eq_y, reaction_indices['R15y']] -= 1   # R15y
            if node == 21:
                A_ga[eq_x, reaction_indices['R21x']] -= 1   # R21x
                A_ga[eq_y, reaction_indices['R21y']] -= 1   # R21y

        return A_ga, B_ga

    def fitness(self, individual):
        current_fixed_member_forces = {
            m: individual[i] for i, m in enumerate(self.seed_fixed_member_ids)
        }
        total_vol = self.compute_total_volume(current_fixed_member_forces)
        return total_vol  # Objective: minimize total volume

    def tournament_selection(self, population, scores):
        selected = []
        for _ in range(self.POPULATION_SIZE):
            aspirants = random.sample(range(len(population)), self.TOURNAMENT_SIZE)
            aspirant_scores = [scores[i] for i in aspirants]
            winner = aspirants[np.argmin(aspirant_scores)]
            selected.append(copy.deepcopy(population[winner]))
        return selected

    def mutate(self, individual, generation):
        # Adaptive mutation amount: decreases over generations
        adaptive_mutation_amount = self.MUTATION_AMOUNT * (1 - generation / self.GENERATIONS)
        for i in range(len(individual)):
            if random.random() < self.MUTATION_RATE:
                mutation = random.uniform(-adaptive_mutation_amount, adaptive_mutation_amount)
                individual[i] += mutation
                # Clamp the gene within bounds
                low, high = self.gene_bounds[i]
                individual[i] = max(low, min(individual[i], high))
        return individual

    def run(self):
        population = self.initialize_population()
        best_volume = float('inf')
        best_individual = None

        for gen in range(1, self.GENERATIONS + 1):
            # Evaluate fitness
            scores = [self.fitness(ind) for ind in population]
            # Find the best individual in current generation
            min_score = min(scores)
            min_index = scores.index(min_score)
            current_best_individual = population[min_index]
            current_best_volume = min_score

            # Update global best
            if current_best_volume < best_volume:
                best_volume = current_best_volume
                best_individual = copy.deepcopy(current_best_individual)
                print(f"Generation {gen}: New Best Volume = {best_volume:.6f} cubic units")
                print("Current Fixed Member Forces:")
                for i, m in enumerate(self.seed_fixed_member_ids):
                    print(f"  Member {m}: {best_individual[i]:.6f} kN")
                print("-" * 50)

            # Selection
            selected = self.tournament_selection(population, scores)

            # Crossover and Mutation
            next_generation = []

            # Elitism: carry over the best individual
            if self.elitism:
                next_generation.append(best_individual)

            while len(next_generation) < self.POPULATION_SIZE:
                parent1 = random.choice(selected)
                parent2 = random.choice(selected)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1, gen)
                child2 = self.mutate(child2, gen)
                next_generation.extend([child1, child2])

            population = next_generation[:self.POPULATION_SIZE]

        return best_individual, best_volume

    def crossover(self, parent1, parent2):
        if random.random() < self.CROSSOVER_RATE:
            point = random.randint(1, len(parent1) - 1)
            child1 = parent1[:point] + parent2[point:]
            child2 = parent2[:point] + parent1[point:]
            return child1, child2
        return copy.deepcopy(parent1), copy.deepcopy(parent2)

# ------------------------- Part 3: Visualization of Optimized Truss -------------------------

def visualize_optimized_truss(truss, optimized_fixed_member_forces, title="Optimized Truss Structure"):
    # Setup equilibrium with optimized fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(optimized_fixed_member_forces.keys()),
        seed_fixed_forces=optimized_fixed_member_forces,
        material_stress=1  # Assuming material_stress is 1 for consistency
    )

    A_ga, B_ga = optimizer.setup_equilibrium(optimized_fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = optimized_fixed_member_forces[m_id]

    # Extract reaction forces
    reaction_forces_ga = F_unknowns_ga[-num_reactions:]

    # Map reactions to indices
    reaction_indices = {}
    for idx, reaction in enumerate(truss.support_reactions):
        reaction_indices[reaction] = idx

    # Plot the Truss
    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Define colors for different member statuses
    tension_color = 'blue'
    compression_color = 'red'
    zero_color = 'gray'
    fixed_color = 'green'

    # Plot each member
    for m_id, (start, end) in truss.members.items():
        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        force = F_full_ga[m_id - 1]

        # Determine color based on force
        if m_id in optimizer.seed_fixed_member_ids:
            color = fixed_color
            linewidth = 2
        else:
            if force > 0:
                color = tension_color
                linewidth = 2
            elif force < 0:
                color = compression_color
                linewidth = 2
            else:
                color = zero_color
                linewidth = 1

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=linewidth)

        # Annotate the force value at the midpoint
        x_mid = (x_start + x_end) / 2
        y_mid = (y_start + y_end) / 2
        if force != 0:
            plt.text(x_mid, y_mid, f"{force:.1f}kN",
                     color='black', fontsize=8, ha='center', va='center')

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Annotate support reactions
    # Node 15 (Pin Support)
    x15, y15 = truss.nodes[15]
    plt.plot(x15, y15, marker='^', markersize=10, markerfacecolor='black', label='Pin Support')
    # Node 21 (Pin Support)
    x21, y21 = truss.nodes[21]
    plt.plot(x21, y21, marker='^', markersize=10, markerfacecolor='black')

    # Create custom legend
    tension_patch = mpatches.Patch(color=tension_color, label='Tension')
    compression_patch = mpatches.Patch(color=compression_color, label='Compression')
    zero_patch = mpatches.Patch(color=zero_color, label='Zero-force')
    fixed_patch = mpatches.Patch(color=fixed_color, label='Fixed Force')
    plt.legend(handles=[tension_patch, compression_patch, zero_patch, fixed_patch], loc='upper right')

    plt.grid(True)
    plt.show()

def plot_cross_section_colored_truss(truss, optimized_fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections"):
    # Setup equilibrium with optimized fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(optimized_fixed_member_forces.keys()),
        seed_fixed_forces=optimized_fixed_member_forces,
        material_stress=material_stress
    )

    A_ga, B_ga = optimizer.setup_equilibrium(optimized_fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = optimized_fixed_member_forces[m_id]

    # Calculate cross-sectional areas and exclude members with zero force or force <1kN
    cross_sections = {}
    for m_id, force in zip(range(1, num_members + 1), F_full_ga):
        if force != 0 and abs(force) >= 1:
            cross_sections[m_id] = abs(force) / material_stress

    if not cross_sections:
        print("No members with non-zero force >= 1kN to plot.")
        return

    # Normalize cross-sectional areas for color mapping
    min_cs = min(cross_sections.values())
    max_cs = max(cross_sections.values())
    if max_cs != min_cs:
        normalized_cs = {m_id: (cs - min_cs) / (max_cs - min_cs) for m_id, cs in cross_sections.items()}
    else:
        normalized_cs = {m_id: 0.5 for m_id in cross_sections}  # All same color

    # Create a custom "dark rainbow" colormap reversed: dark blue to red
    dark_rainbow = LinearSegmentedColormap.from_list('dark_rainbow', ['darkblue', 'lightblue', 'green', 'yellow', 'orange', 'red'])

    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Plot each member with color based on normalized cross-section
    for m_id, (start, end) in truss.members.items():
        if m_id not in cross_sections:
            continue  # Skip members with zero force or force <1kN

        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        normalized_value = normalized_cs[m_id]
        color = dark_rainbow(normalized_value)

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=2)

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Plot supports without reactions
    # Node 15 (Pin Support)
    x15, y15 = truss.nodes[15]
    plt.plot(x15, y15, marker='^', markersize=10, markerfacecolor='black', label='Pin Support')
    # Node 21 (Pin Support)
    x21, y21 = truss.nodes[21]
    plt.plot(x21, y21, marker='^', markersize=10, markerfacecolor='black')

    # Create a colorbar
    sm = plt.cm.ScalarMappable(cmap=dark_rainbow, norm=plt.Normalize(vmin=min_cs, vmax=max_cs))
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, shrink=0.6)
    cbar.set_label('Cross-Sectional Area (normalized)')

    # Create custom legend for supports
    pin_patch = Line2D([0], [0], marker='^', color='w', label='Pin Support',
                       markerfacecolor='black', markersize=10)
    plt.legend(handles=[pin_patch], loc='upper right')

    plt.grid(True)
    plt.show()

# ------------------------- Utility Function -------------------------

def select_random_fixed_members(truss, N):
    total_members = len(truss.members)
    if N > total_members:
        raise ValueError(f"Cannot select {N} members as there are only {total_members} members.")
    fixed_member_ids = random.sample(range(1, total_members + 1), N)
    return fixed_member_ids

# ------------------------- Main Execution -------------------------

if __name__ == "__main__":
    # Set random seeds for reproducibility (optional)
    if USE_SEED:
        random.seed(42)
        np.random.seed(42)
        print("Random seeds are set for reproducibility.\n")
    else:
        print("Random seeds are not set. Results may vary with each run.\n")

    # Initialize the truss
    truss = Truss()

    # Compute degree of indeterminacy
    truss.compute_degree_of_indeterminacy()
    print(f"Degree of Indeterminacy: {truss.degree_of_indeterminacy}\n")

    # Determine fixed members based on user configuration
    N = truss.degree_of_indeterminacy
    if SPECIFY_FIXED_MEMBERS:
        if len(SPECIFIED_FIXED_MEMBER_IDS) != N:
            print(f"Error: Number of specified fixed members ({len(SPECIFIED_FIXED_MEMBER_IDS)}) does not match the degree of indeterminacy ({N}).")
            exit(1)
        fixed_member_ids = SPECIFIED_FIXED_MEMBER_IDS
    else:
        fixed_member_ids = select_random_fixed_members(truss, N)

    # Assign the fixed_member_ids to the truss
    truss.fixed_member_ids = fixed_member_ids

    # Generate random initial forces for the fixed members between 0 and 50
    seed_fixed_forces = {m_id: random.uniform(0, 50) for m_id in fixed_member_ids}

    # Print selected fixed members and their initial random forces
    print("--- Genetic Algorithm Optimization ---\n")
    print(f"Selected Fixed Members (Total {N}):")
    for m_id, force in seed_fixed_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print("\nStarting Genetic Algorithm...\n")

    # Initialize and run the genetic algorithm optimizer
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=fixed_member_ids,
        seed_fixed_forces=seed_fixed_forces,
        material_stress=1,          # Adjust based on material properties
        population_size=200,        # Increased population size for diversity
        generations=500,            # Increased number of generations
        tournament_size=3,          # Number of individuals competing in tournament selection
        crossover_rate=0.8,         # Probability of crossover
        mutation_rate=0.5,          # Increased mutation rate
        mutation_amount=20,         # Increased mutation amount
        elitism=True                # Use elitism to preserve the best individual
    )

    best_individual, best_volume = optimizer.run()

    # Map the best individual to fixed member forces
    optimized_fixed_member_forces = {m_id: best_individual[i] for i, m_id in enumerate(fixed_member_ids)}

    # Print optimization results
    print("\n--- Optimization Results ---\n")
    print("Optimized Fixed Member Forces:")
    for m_id, force in optimized_fixed_member_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print(f"\nMinimum Structure Volume Achieved: {best_volume:.6f} cubic units\n")

    # Visualize the optimized truss
    visualize_optimized_truss(truss, optimized_fixed_member_forces, title="Optimized Truss Structure with Minimized Volume")

    # Plot the cross-section normalized truss
    plot_cross_section_colored_truss(truss, optimized_fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections")
# Out:
# Random seeds are not set. Results may vary with each run.
#
# Degree of Indeterminacy: 6
#
# --- Genetic Algorithm Optimization ---
#
# Selected Fixed Members (Total 6):
#   Member 15: 44.958426 kN
#   Member 4: 17.065950 kN
#   Member 33: 1.141342 kN
#   Member 34: 23.868369 kN
#   Member 41: 6.397657 kN
#   Member 42: 34.923846 kN
#
# Starting Genetic Algorithm...
#
# Generation 1: New Best Volume = 570.334713 cubic units
# Current Fixed Member Forces:
#   Member 15: 4.858984 kN
#   Member 4: 8.489659 kN
#   Member 33: 5.073306 kN
#   Member 34: -24.731506 kN
#   Member 41: -2.666534 kN
#   Member 42: 8.876343 kN
# --------------------------------------------------
# Generation 2: New Best Volume = 509.446069 cubic units
# Current Fixed Member Forces:
#   Member 15: 2.760524 kN
#   Member 4: 31.945139 kN
#   Member 33: -0.596182 kN
#   Member 34: -38.192414 kN
#   Member 41: -24.060272 kN
#   Member 42: 6.537744 kN
# --------------------------------------------------
# Generation 3: New Best Volume = 500.997635 cubic units
# Current Fixed Member Forces:
#   Member 15: 4.858984 kN
#   Member 4: 17.227329 kN
#   Member 33: -14.923280 kN
#   Member 34: -37.042390 kN
#   Member 41: -17.891782 kN
#   Member 42: -2.160514 kN
# --------------------------------------------------
# Generation 4: New Best Volume = 493.585256 cubic units
# Current Fixed Member Forces:
#   Member 15: 4.858984 kN
#   Member 4: 17.227329 kN
#   Member 33: -14.923280 kN
#   Member 34: -37.042390 kN
#   Member 41: -17.891782 kN
#   Member 42: 5.982836 kN
# --------------------------------------------------
# Generation 5: New Best Volume = 472.574773 cubic units
# Current Fixed Member Forces:
#   Member 15: -2.278508 kN
#   Member 4: 13.274214 kN
#   Member 33: -8.035014 kN
#   Member 34: -26.971852 kN
#   Member 41: -26.558391 kN
#   Member 42: 3.092152 kN
# --------------------------------------------------
# Generation 6: New Best Volume = 445.709244 cubic units
# Current Fixed Member Forces:
#   Member 15: 8.382201 kN
#   Member 4: 11.298310 kN
#   Member 33: -0.861834 kN
#   Member 34: -15.376337 kN
#   Member 41: -13.412205 kN
#   Member 42: 2.847707 kN
# --------------------------------------------------
# Generation 7: New Best Volume = 387.131646 cubic units
# Current Fixed Member Forces:
#   Member 15: -9.794432 kN
#   Member 4: 11.298310 kN
#   Member 33: -0.861834 kN
#   Member 34: -15.376337 kN
#   Member 41: -13.412205 kN
#   Member 42: 3.866593 kN
# --------------------------------------------------
# Generation 21: New Best Volume = 365.854070 cubic units
# Current Fixed Member Forces:
#   Member 15: -4.213686 kN
#   Member 4: 18.861405 kN
#   Member 33: 7.539760 kN
#   Member 34: -17.333608 kN
#   Member 41: -20.178293 kN
#   Member 42: 5.700770 kN
# --------------------------------------------------
# Generation 38: New Best Volume = 359.612257 cubic units
# Current Fixed Member Forces:
#   Member 15: -3.984496 kN
#   Member 4: 18.842193 kN
#   Member 33: 5.377564 kN
#   Member 34: -17.333608 kN
#   Member 41: -19.478988 kN
#   Member 42: 1.119493 kN
# --------------------------------------------------
# Generation 79: New Best Volume = 348.832748 cubic units
# Current Fixed Member Forces:
#   Member 15: 0.590113 kN
#   Member 4: 20.627201 kN
#   Member 33: 1.409959 kN
#   Member 34: -23.550855 kN
#   Member 41: -23.623444 kN
#   Member 42: 0.579209 kN
# --------------------------------------------------
# Generation 122: New Best Volume = 346.589298 cubic units
# Current Fixed Member Forces:
#   Member 15: 0.590113 kN
#   Member 4: 21.003979 kN
#   Member 33: 1.409959 kN
#   Member 34: -23.550855 kN
#   Member 41: -23.623444 kN
#   Member 42: 0.579209 kN
# --------------------------------------------------
# Generation 123: New Best Volume = 343.365377 cubic units
# Current Fixed Member Forces:
#   Member 15: 0.590113 kN
#   Member 4: 21.003979 kN
#   Member 33: 1.409959 kN
#   Member 34: -21.148559 kN
#   Member 41: -23.623444 kN
#   Member 42: -0.492063 kN
# --------------------------------------------------
# Generation 319: New Best Volume = 339.441953 cubic units
# Current Fixed Member Forces:
#   Member 15: 0.590113 kN
#   Member 4: 20.622647 kN
#   Member 33: 1.409959 kN
#   Member 34: -21.148559 kN
#   Member 41: -22.779121 kN
#   Member 42: 0.431375 kN
# --------------------------------------------------
# Generation 355: New Best Volume = 339.182934 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.204771 kN
#   Member 4: 19.563142 kN
#   Member 33: 2.036861 kN
#   Member 34: -20.602065 kN
#   Member 41: -21.541477 kN
#   Member 42: 0.099602 kN
# --------------------------------------------------
# Generation 356: New Best Volume = 338.848144 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.490568 kN
#   Member 4: 19.315843 kN
#   Member 33: 0.565526 kN
#   Member 34: -19.933189 kN
#   Member 41: -20.663954 kN
#   Member 42: 0.431375 kN
# --------------------------------------------------
# Generation 358: New Best Volume = 338.682883 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.204771 kN
#   Member 4: 19.520044 kN
#   Member 33: 0.099627 kN
#   Member 34: -21.159848 kN
#   Member 41: -19.863189 kN
#   Member 42: 0.595633 kN
# --------------------------------------------------
# Generation 370: New Best Volume = 336.789855 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.518885 kN
#   Member 4: 18.949188 kN
#   Member 33: -0.434311 kN
#   Member 34: -21.159848 kN
#   Member 41: -20.464624 kN
#   Member 42: -0.046488 kN
# --------------------------------------------------
# Generation 411: New Best Volume = 334.740392 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.723747 kN
#   Member 4: 19.179571 kN
#   Member 33: -0.017482 kN
#   Member 34: -21.159848 kN
#   Member 41: -20.464624 kN
#   Member 42: -0.046488 kN
# --------------------------------------------------
# Generation 441: New Best Volume = 333.625603 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.385054 kN
#   Member 4: 19.757673 kN
#   Member 33: 0.252333 kN
#   Member 34: -20.915960 kN
#   Member 41: -21.706113 kN
#   Member 42: -0.046488 kN
# --------------------------------------------------
# Generation 452: New Best Volume = 333.391003 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.385054 kN
#   Member 4: 19.757673 kN
#   Member 33: 0.252333 kN
#   Member 34: -20.915960 kN
#   Member 41: -20.879072 kN
#   Member 42: -0.046488 kN
# --------------------------------------------------
# Generation 464: New Best Volume = 332.303264 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.385054 kN
#   Member 4: 19.757673 kN
#   Member 33: 0.252333 kN
#   Member 34: -20.915960 kN
#   Member 41: -21.281924 kN
#   Member 42: 0.251495 kN
# --------------------------------------------------
# Generation 486: New Best Volume = 332.228699 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.130786 kN
#   Member 4: 19.907916 kN
#   Member 33: -0.100370 kN
#   Member 34: -21.311591 kN
#   Member 41: -21.020428 kN
#   Member 42: 0.331243 kN
# --------------------------------------------------
# Generation 487: New Best Volume = 331.834778 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.067642 kN
#   Member 4: 19.894402 kN
#   Member 33: 0.169326 kN
#   Member 34: -21.177842 kN
#   Member 41: -21.256222 kN
#   Member 42: -0.156924 kN
# --------------------------------------------------
# Generation 489: New Best Volume = 331.821519 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.089797 kN
#   Member 4: 20.117715 kN
#   Member 33: 0.452057 kN
#   Member 34: -21.209886 kN
#   Member 41: -21.264522 kN
#   Member 42: 0.453835 kN
# --------------------------------------------------
# Generation 492: New Best Volume = 331.693528 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.232306 kN
#   Member 4: 20.001655 kN
#   Member 33: 0.396825 kN
#   Member 34: -21.252036 kN
#   Member 41: -21.183976 kN
#   Member 42: 0.178693 kN
# --------------------------------------------------
# Generation 493: New Best Volume = 331.656707 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.230709 kN
#   Member 4: 19.848463 kN
#   Member 33: 0.098710 kN
#   Member 34: -20.972371 kN
#   Member 41: -21.248034 kN
#   Member 42: 0.102680 kN
# --------------------------------------------------
# Generation 494: New Best Volume = 331.025365 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.125954 kN
#   Member 4: 20.056383 kN
#   Member 33: 0.301077 kN
#   Member 34: -21.225453 kN
#   Member 41: -21.197979 kN
#   Member 42: 0.189054 kN
# --------------------------------------------------
# Generation 498: New Best Volume = 330.769095 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.032751 kN
#   Member 4: 20.095737 kN
#   Member 33: 0.048772 kN
#   Member 34: -21.309972 kN
#   Member 41: -21.193000 kN
#   Member 42: 0.219685 kN
# --------------------------------------------------
# Generation 500: New Best Volume = 330.733472 cubic units
# Current Fixed Member Forces:
#   Member 15: -0.032751 kN
#   Member 4: 20.095737 kN
#   Member 33: 0.048772 kN
#   Member 34: -21.309972 kN
#   Member 41: -21.193000 kN
#   Member 42: 0.207091 kN
# --------------------------------------------------
#
# --- Optimization Results ---
#
# Optimized Fixed Member Forces:
#   Member 15: -0.032751 kN
#   Member 4: 20.095737 kN
#   Member 33: 0.048772 kN
#   Member 34: -21.309972 kN
#   Member 41: -21.193000 kN
#   Member 42: 0.207091 kN
#
# Minimum Structure Volume Achieved: 330.733472 cubic units

# %% [markdown]
# ## Definable code at the start

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.colors import LinearSegmentedColormap
import random
import copy

# ------------------------- Configuration -------------------------

USE_SEED = False  # Set to False to disable fixed random seed

# New Configuration Options
SPECIFY_FIXED_MEMBERS = True  # Set to True to specify fixed members manually
SPECIFIED_FIXED_MEMBER_IDS = [34, 33, 21, 26, 42, 41]  # List of member IDs to fix

# Truss Configuration
COLUMNS = 7  # Number of columns of nodes
ROWS = 3     # Number of rows of nodes

# Load Nodes: {node_id: [Fx, Fy], ...}
# Nodes 3, 6, 9, 12, 15, 18, 21 have a load of [0, -10]
LOAD_NODES = {
    3: [0, -10],
    6: [0, -10],
    9: [0, -10],
    12: [0, -10],
    15: [0, -10],
    18: [0, -10],
    21: [0, -10]
}

# Support Nodes: {node_id: [Restrain_x (1 or 0), Restrain_y (1 or 0)], ...}
# Nodes 1 and 19 are supports restrained in x and y
SUPPORT_NODES = {
    1: [1, 1],
    19: [1, 1]
}

# ------------------------- Part 1: Truss Definition -------------------------

class Truss:
    def __init__(self, columns=COLUMNS, rows=ROWS, load_nodes=LOAD_NODES, support_nodes=SUPPORT_NODES):
        self.columns = columns
        self.rows = rows
        self.nodes = {}
        self.members = {}
        self.external_loads = load_nodes  # {node_id: [Fx, Fy], ...}
        self.support_nodes = support_nodes  # {node_id: [Restrain_x, Restrain_y], ...}
        self.support_reactions = {}  # Will be populated based on support_nodes
        self.fixed_member_ids = []  # To be set dynamically based on degree of indeterminacy
        self.degree_of_indeterminacy = 0
        self.direction_cosines_cache = {}
        self.initialize_truss()

    def initialize_truss(self):
        self.define_nodes()
        self.define_members()
        self.define_support_reactions()
        self.compute_degree_of_indeterminacy()

    def define_nodes(self):
        node_id = 1
        for x in range(self.columns):       # x=0 to x=COLUMNS-1
            for y in range(self.rows):      # y=0 to y=ROWS-1
                self.nodes[node_id] = (x, y)
                node_id += 1

    def add_member(self, start, end):
        if start not in self.nodes or end not in self.nodes:
            print(f"Skipping member ({start}, {end}) - Invalid node number.")
            return
        # Avoid duplicate members
        if not any(
            (start == existing_start and end == existing_end) or
            (start == existing_end and end == existing_start)
            for existing_start, existing_end in self.members.values()
        ):
            self.members[len(self.members) + 1] = (start, end)

    def define_members(self):
        # Add vertical members
        for x in range(self.columns):
            for y in range(self.rows - 1):
                node_start = x * self.rows + y + 1
                node_end = node_start + 1
                self.add_member(node_start, node_end)

        # Add horizontal members
        for x in range(self.columns - 1):
            for y in range(self.rows):
                node_start = x * self.rows + y + 1
                node_end = (x + 1) * self.rows + y + 1
                self.add_member(node_start, node_end)

        # Add diagonal members at special nodes
        for x in range(self.columns):
            for y in range(self.rows):
                # Identify special nodes (every second node in every second column)
                if x % 2 == 1 and y % 2 == 1:
                    current_node = x * self.rows + y + 1
                    # Top-right diagonal
                    if x < self.columns - 1 and y < self.rows - 1:
                        node_tr = (x + 1) * self.rows + y + 2
                        self.add_member(current_node, node_tr)
                    # Top-left diagonal
                    if x > 0 and y < self.rows - 1:
                        node_tl = (x - 1) * self.rows + y + 2
                        self.add_member(current_node, node_tl)
                    # Bottom-left diagonal
                    if x > 0 and y > 0:
                        node_bl = (x - 1) * self.rows + y
                        self.add_member(current_node, node_bl)
                    # Bottom-right diagonal
                    if x < self.columns - 1 and y > 0:
                        node_br = (x + 1) * self.rows + y
                        self.add_member(current_node, node_br)

    def find_node(self, x, y):
        for nid, coord in self.nodes.items():
            if coord == (x, y):
                return nid
        return None

    def define_support_reactions(self):
        # For each support node, define reactions based on restraints
        self.support_reactions = {}
        for node_id, restraints in self.support_nodes.items():
            restrain_x, restrain_y = restraints
            if restrain_x:
                self.support_reactions[f'R{node_id}x'] = None
            if restrain_y:
                self.support_reactions[f'R{node_id}y'] = None

    def compute_degree_of_indeterminacy(self):
        num_reactions = len(self.support_reactions)
        num_members = len(self.members)
        num_nodes = len(self.nodes)
        self.degree_of_indeterminacy = num_members + num_reactions - 2 * num_nodes

    def direction_cosines(self, start, end):
        key = tuple(sorted((start, end)))
        if key in self.direction_cosines_cache:
            return self.direction_cosines_cache[key]
        x1, y1 = self.nodes[start]
        x2, y2 = self.nodes[end]
        delta_x = x2 - x1
        delta_y = y2 - y1
        length = np.sqrt(delta_x**2 + delta_y**2)
        if length == 0:
            raise ValueError(f"Zero length member between nodes {start} and {end}.")
        cos_theta = delta_x / length
        sin_theta = delta_y / length
        self.direction_cosines_cache[key] = (cos_theta, sin_theta)
        return cos_theta, sin_theta

# ------------------------- Part 2: Genetic Algorithm for Minimum Truss Volume -------------------------

class GeneticAlgorithmOptimizer:
    def __init__(self, truss, seed_fixed_member_ids, seed_fixed_forces,
                 material_stress=1, population_size=200, generations=200,
                 tournament_size=3, crossover_rate=0.8, mutation_rate=0.5, mutation_amount=10, elitism=True):
        self.truss = truss
        self.seed_fixed_member_ids = seed_fixed_member_ids
        self.seed_fixed_forces = seed_fixed_forces
        self.material_stress = material_stress

        # Genetic Algorithm Parameters
        self.POPULATION_SIZE = population_size
        self.GENERATIONS = generations
        self.TOURNAMENT_SIZE = tournament_size
        self.CROSSOVER_RATE = crossover_rate
        self.MUTATION_RATE = mutation_rate
        self.MUTATION_AMOUNT = mutation_amount
        self.elitism = elitism

        # Define gene bounds (-50 to 50)
        self.gene_bounds = [(-50, 50) for _ in self.seed_fixed_forces]

        # Create mappings
        self.fixed_member_indices = [m - 1 for m in self.seed_fixed_member_ids]
        self.unknown_member_indices = [
            i for i in range(len(truss.members)) if i not in self.fixed_member_indices
        ]
        self.num_reactions = len(truss.support_reactions)
        self.num_members = len(truss.members)
        self.num_unknowns_ga = len(self.unknown_member_indices) + self.num_reactions

        # Mapping from member index to unknown index
        self.member_index_to_unknown = {
            i: idx for idx, i in enumerate(self.unknown_member_indices)
        }

        # Mapping for reaction indices
        self.reaction_indices = {}
        for idx, reaction in enumerate(self.truss.support_reactions):
            self.reaction_indices[reaction] = len(self.unknown_member_indices) + idx

    def initialize_population(self):
        population = []
        for _ in range(self.POPULATION_SIZE):
            individual = [
                random.uniform(low, high) for (low, high) in self.gene_bounds
            ]
            population.append(individual)
        return population

    def compute_total_volume(self, current_fixed_member_forces):
        A_ga, B_ga = self.setup_equilibrium(current_fixed_member_forces)
        try:
            F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
            equilibrium_satisfied_ga = True
        except np.linalg.LinAlgError:
            F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)
            equilibrium_satisfied_ga = False

        # Check equilibrium
        B_calculated = np.dot(A_ga, F_unknowns_ga)
        difference = B_calculated - B_ga
        tolerance = 1e-5  # Adjust tolerance as needed
        if np.any(np.abs(difference) > tolerance):
            # Equilibrium not satisfied, return a large fitness value
            return 1e10  # Large penalty
        else:
            # Reconstruct full member forces
            F_full_ga = np.zeros(self.num_members)
            for member_index in self.unknown_member_indices:
                unknown_idx = self.member_index_to_unknown[member_index]
                F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
            for i, m_id in enumerate(self.seed_fixed_member_ids):
                F_full_ga[m_id - 1] = current_fixed_member_forces[m_id]

            # Calculate total volume
            total_volume = 0.0
            for m_id, (start, end) in self.truss.members.items():
                x1, y1 = self.truss.nodes[start]
                x2, y2 = self.truss.nodes[end]
                length = np.sqrt((x2 - x1)**2 + (y2 - y1)**2)
                force_magnitude = abs(F_full_ga[m_id - 1])
                cross_sectional_area = force_magnitude / self.material_stress
                volume = cross_sectional_area * length
                total_volume += volume

            return total_volume

    def setup_equilibrium(self, current_fixed_member_forces):
        num_members = self.num_members
        num_reactions = self.num_reactions
        num_nodes = len(self.truss.nodes)
        equations_per_node = 2
        total_equations = num_nodes * equations_per_node
        total_unknowns = self.num_unknowns_ga

        A_ga = np.zeros((total_equations, total_unknowns))
        B_ga = np.zeros(total_equations)

        # Map reactions to indices
        reaction_indices = self.reaction_indices

        for node in self.truss.nodes:
            eq_x = (node - 1) * 2
            eq_y = eq_x + 1

            # Assign external loads
            load = self.truss.external_loads.get(node, [0, 0])
            B_ga[eq_x] += load[0]
            B_ga[eq_y] += load[1]

            # Iterate through connected members
            for m_id, (start, end) in self.truss.members.items():
                member_index = m_id - 1
                if node == start or node == end:
                    other = end if node == start else start
                    cos_theta, sin_theta = self.truss.direction_cosines(node, other)
                    coef_x = cos_theta if node == start else -cos_theta
                    coef_y = sin_theta if node == start else -sin_theta

                    if m_id in current_fixed_member_forces:
                        fixed_force = current_fixed_member_forces[m_id]
                        B_ga[eq_x] -= coef_x * fixed_force
                        B_ga[eq_y] -= coef_y * fixed_force
                    else:
                        if member_index in self.member_index_to_unknown:
                            unknown_idx = self.member_index_to_unknown[member_index]
                            A_ga[eq_x, unknown_idx] += coef_x
                            A_ga[eq_y, unknown_idx] += coef_y

            # Assign support reactions
            if node in self.truss.support_nodes:
                restraints = self.truss.support_nodes[node]
                restrain_x, restrain_y = restraints
                if restrain_x:
                    reaction_name = f'R{node}x'
                    A_ga[eq_x, reaction_indices[reaction_name]] -= 1
                if restrain_y:
                    reaction_name = f'R{node}y'
                    A_ga[eq_y, reaction_indices[reaction_name]] -= 1

        return A_ga, B_ga

    def fitness(self, individual):
        current_fixed_member_forces = {
            m: individual[i] for i, m in enumerate(self.seed_fixed_member_ids)
        }
        total_vol = self.compute_total_volume(current_fixed_member_forces)
        return total_vol  # Objective: minimize total volume

    def tournament_selection(self, population, scores):
        selected = []
        for _ in range(self.POPULATION_SIZE):
            aspirants = random.sample(range(len(population)), self.TOURNAMENT_SIZE)
            aspirant_scores = [scores[i] for i in aspirants]
            winner = aspirants[np.argmin(aspirant_scores)]
            selected.append(copy.deepcopy(population[winner]))
        return selected

    def mutate(self, individual, generation):
        # Adaptive mutation amount: decreases over generations
        adaptive_mutation_amount = self.MUTATION_AMOUNT * (1 - generation / self.GENERATIONS)
        for i in range(len(individual)):
            if random.random() < self.MUTATION_RATE:
                mutation = random.uniform(-adaptive_mutation_amount, adaptive_mutation_amount)
                individual[i] += mutation
                # Clamp the gene within bounds
                low, high = self.gene_bounds[i]
                individual[i] = max(low, min(individual[i], high))
        return individual

    def run(self):
        population = self.initialize_population()
        best_volume = float('inf')
        best_individual = None

        for gen in range(1, self.GENERATIONS + 1):
            # Evaluate fitness
            scores = [self.fitness(ind) for ind in population]
            # Find the best individual in current generation
            min_score = min(scores)
            min_index = scores.index(min_score)
            current_best_individual = population[min_index]
            current_best_volume = min_score

            # Update global best
            if current_best_volume < best_volume:
                best_volume = current_best_volume
                best_individual = copy.deepcopy(current_best_individual)
                print(f"Generation {gen}: New Best Volume = {best_volume:.6f} cubic units")
                print("Current Fixed Member Forces:")
                for i, m in enumerate(self.seed_fixed_member_ids):
                    print(f"  Member {m}: {best_individual[i]:.6f} kN")
                print("-" * 50)

            # Selection
            selected = self.tournament_selection(population, scores)

            # Crossover and Mutation
            next_generation = []

            # Elitism: carry over the best individual
            if self.elitism:
                next_generation.append(best_individual)

            while len(next_generation) < self.POPULATION_SIZE:
                parent1 = random.choice(selected)
                parent2 = random.choice(selected)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1, gen)
                child2 = self.mutate(child2, gen)
                next_generation.extend([child1, child2])

            population = next_generation[:self.POPULATION_SIZE]

        return best_individual, best_volume

    def crossover(self, parent1, parent2):
        if random.random() < self.CROSSOVER_RATE:
            point = random.randint(1, len(parent1) - 1)
            child1 = parent1[:point] + parent2[point:]
            child2 = parent2[:point] + parent1[point:]
            return child1, child2
        return copy.deepcopy(parent1), copy.deepcopy(parent2)

# ------------------------- Part 3: Visualization of Truss -------------------------

def visualize_truss(truss, fixed_member_forces, title="Truss Structure"):
    """
    Visualize the truss structure with member forces and Member IDs.
    """
    # Setup equilibrium with given fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(fixed_member_forces.keys()),
        seed_fixed_forces=fixed_member_forces,
        material_stress=1  # Assuming material_stress is 1 for consistency
    )

    A_ga, B_ga = optimizer.setup_equilibrium(fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = fixed_member_forces[m_id]

    # Plot the Truss
    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Define colors for different member statuses
    tension_color = 'blue'
    compression_color = 'red'
    zero_color = 'gray'
    fixed_color = 'green'

    # Plot each member
    for m_id, (start, end) in truss.members.items():
        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        force = F_full_ga[m_id - 1]

        # Determine color based on force
        if m_id in optimizer.seed_fixed_member_ids:
            color = fixed_color
            linewidth = 2
        else:
            if force > 0:
                color = tension_color
                linewidth = 2
            elif force < 0:
                color = compression_color
                linewidth = 2
            else:
                color = zero_color
                linewidth = 1

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=linewidth)

        # Annotate the force value at the midpoint
        x_mid = (x_start + x_end) / 2
        y_mid = (y_start + y_end) / 2
        if force != 0:
            plt.text(x_mid, y_mid, f"{force:.1f}kN",
                     color='black', fontsize=8, ha='center', va='center')

        # Annotate the Member ID slightly offset from the midpoint
        offset = 0.1  # Adjust as needed for clarity
        plt.text(x_mid + offset, y_mid + offset, f"ID:{m_id}",
                 color='purple', fontsize=8, ha='center', va='center')

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Plot supports
    support_plotted = False
    for node_id, restraints in truss.support_nodes.items():
        x, y = truss.nodes[node_id]
        plt.plot(x, y, marker='^', markersize=10, markerfacecolor='black',
                 label='Support' if not support_plotted else "")
        support_plotted = True

    # Create custom legend
    tension_patch = mpatches.Patch(color=tension_color, label='Tension')
    compression_patch = mpatches.Patch(color=compression_color, label='Compression')
    zero_patch = mpatches.Patch(color=zero_color, label='Zero-force')
    fixed_patch = mpatches.Patch(color=fixed_color, label='Fixed Force')
    handles = [tension_patch, compression_patch, zero_patch, fixed_patch]
    if support_plotted:
        pin_patch = Line2D([0], [0], marker='^', color='w', label='Support',
                           markerfacecolor='black', markersize=10)
        handles.append(pin_patch)
    plt.legend(handles=handles, loc='upper right')

    plt.grid(True)
    plt.show()

def plot_cross_section_colored_truss(truss, fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections"):
    """
    Plot the truss with cross-sectional areas colored based on normalized values.
    """
    # Setup equilibrium with given fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(fixed_member_forces.keys()),
        seed_fixed_forces=fixed_member_forces,
        material_stress=material_stress
    )

    A_ga, B_ga = optimizer.setup_equilibrium(fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = fixed_member_forces[m_id]

    # Calculate cross-sectional areas and exclude members with zero force or force <1kN
    cross_sections = {}
    for m_id, force in zip(range(1, num_members + 1), F_full_ga):
        if force != 0 and abs(force) >= 1:
            cross_sections[m_id] = abs(force) / material_stress

    if not cross_sections:
        print("No members with non-zero force >= 1kN to plot.")
        return

    # Normalize cross-sectional areas for color mapping
    min_cs = min(cross_sections.values())
    max_cs = max(cross_sections.values())
    if max_cs != min_cs:
        normalized_cs = {m_id: (cs - min_cs) / (max_cs - min_cs) for m_id, cs in cross_sections.items()}
    else:
        normalized_cs = {m_id: 0.5 for m_id in cross_sections}  # All same color

    # Create a custom "dark rainbow" colormap reversed: dark blue to red
    dark_rainbow = LinearSegmentedColormap.from_list('dark_rainbow', ['darkblue', 'lightblue', 'green', 'yellow', 'orange', 'red'])

    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Plot each member with color based on normalized cross-section
    for m_id, (start, end) in truss.members.items():
        if m_id not in cross_sections:
            continue  # Skip members with zero force or force <1kN

        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        normalized_value = normalized_cs[m_id]
        color = dark_rainbow(normalized_value)

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=2)

        # Annotate the Member ID slightly offset from the midpoint
        x_mid = (x_start + x_end) / 2
        y_mid = (y_start + y_end) / 2
        offset = 0.1  # Adjust as needed for clarity
        plt.text(x_mid + offset, y_mid + offset, f"ID:{m_id}",
                 color='purple', fontsize=8, ha='center', va='center')

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Plot supports
    support_plotted = False
    for node_id, restraints in truss.support_nodes.items():
        x, y = truss.nodes[node_id]
        plt.plot(x, y, marker='^', markersize=10, markerfacecolor='black',
                 label='Support' if not support_plotted else "")
        support_plotted = True

    # Create a colorbar
    sm = plt.cm.ScalarMappable(cmap=dark_rainbow, norm=plt.Normalize(vmin=min_cs, vmax=max_cs))
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, shrink=0.6)
    cbar.set_label('Cross-Sectional Area (normalized)')

    # Create custom legend for supports
    handles = []
    tension_patch = mpatches.Patch(color='blue', label='Tension')
    compression_patch = mpatches.Patch(color='red', label='Compression')
    zero_patch = mpatches.Patch(color='gray', label='Zero-force')
    fixed_patch = mpatches.Patch(color='green', label='Fixed Force')
    handles.extend([tension_patch, compression_patch, zero_patch, fixed_patch])
    if support_plotted:
        pin_patch = Line2D([0], [0], marker='^', color='w', label='Support',
                           markerfacecolor='black', markersize=10)
        handles.append(pin_patch)
    plt.legend(handles=handles, loc='upper right')

    plt.grid(True)
    plt.show()

# ------------------------- Utility Function -------------------------

def select_random_fixed_members(truss, N):
    total_members = len(truss.members)
    if N > total_members:
        raise ValueError(f"Cannot select {N} members as there are only {total_members} members.")
    fixed_member_ids = random.sample(range(1, total_members + 1), N)
    return fixed_member_ids

# ------------------------- Main Execution -------------------------

if __name__ == "__main__":
    # Set random seeds for reproducibility (optional)
    if USE_SEED:
        random.seed(42)
        np.random.seed(42)
        print("Random seeds are set for reproducibility.\n")
    else:
        print("Random seeds are not set. Results may vary with each run.\n")

    # Initialize the truss
    truss = Truss()

    # Compute degree of indeterminacy
    truss.compute_degree_of_indeterminacy()
    print(f"Degree of Indeterminacy: {truss.degree_of_indeterminacy}\n")

    # Determine fixed members based on user configuration
    N = truss.degree_of_indeterminacy
    if SPECIFY_FIXED_MEMBERS:
        if len(SPECIFIED_FIXED_MEMBER_IDS) != N:
            print(f"Error: Number of specified fixed members ({len(SPECIFIED_FIXED_MEMBER_IDS)}) does not match the degree of indeterminacy ({N}).")
            exit(1)
        fixed_member_ids = SPECIFIED_FIXED_MEMBER_IDS
    else:
        fixed_member_ids = select_random_fixed_members(truss, N)

    # Assign the fixed_member_ids to the truss
    truss.fixed_member_ids = fixed_member_ids

    # Generate random initial forces for the fixed members between -50 and 50
    seed_fixed_forces = {m_id: random.uniform(-50, 50) for m_id in fixed_member_ids}

    # Print selected fixed members and their initial random forces
    print("--- Genetic Algorithm Optimization ---\n")
    print(f"Selected Fixed Members (Total {N}):")
    for m_id, force in seed_fixed_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print("\nVisualizing Initial Truss Structure...\n")

    # Visualize the initial truss before optimization
    visualize_truss(truss, seed_fixed_forces, title="Initial Truss Structure")

    print("\nStarting Genetic Algorithm...\n")

    # Initialize and run the genetic algorithm optimizer
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=fixed_member_ids,
        seed_fixed_forces=seed_fixed_forces,
        material_stress=1,          # Adjust based on material properties
        population_size=200,        # Increased population size for diversity
        generations=500,            # Increased number of generations
        tournament_size=3,          # Number of individuals competing in tournament selection
        crossover_rate=0.8,         # Probability of crossover
        mutation_rate=0.5,          # Increased mutation rate
        mutation_amount=20,         # Increased mutation amount
        elitism=True                # Use elitism to preserve the best individual
    )

    best_individual, best_volume = optimizer.run()

    # Map the best individual to fixed member forces
    optimized_fixed_member_forces = {m_id: best_individual[i] for i, m_id in enumerate(fixed_member_ids)}

    # Print optimization results
    print("\n--- Optimization Results ---\n")
    print("Optimized Fixed Member Forces:")
    for m_id, force in optimized_fixed_member_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print(f"\nMinimum Structure Volume Achieved: {best_volume:.6f} cubic units\n")

    # Visualize the optimized truss
    visualize_truss(truss, optimized_fixed_member_forces, title="Optimized Truss Structure with Minimized Volume")

    # Plot the cross-section normalized truss
    plot_cross_section_colored_truss(truss, optimized_fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections")
# Out:
# Random seeds are not set. Results may vary with each run.
#
# Degree of Indeterminacy: 6
#
# --- Genetic Algorithm Optimization ---
#
# Selected Fixed Members (Total 6):
#   Member 34: -38.656719 kN
#   Member 33: 7.878185 kN
#   Member 21: 37.522090 kN
#   Member 26: 13.045478 kN
#   Member 42: 46.310591 kN
#   Member 41: -33.851445 kN
#
# Visualizing Initial Truss Structure...
# Starting Genetic Algorithm...
#
# Generation 1: New Best Volume = 686.048914 cubic units
# Current Fixed Member Forces:
#   Member 34: -13.332820 kN
#   Member 33: 22.056017 kN
#   Member 21: -36.837591 kN
#   Member 26: 1.925201 kN
#   Member 42: 6.433820 kN
#   Member 41: -15.554501 kN
# --------------------------------------------------
# Generation 2: New Best Volume = 603.644095 cubic units
# Current Fixed Member Forces:
#   Member 34: -8.539568 kN
#   Member 33: 19.032892 kN
#   Member 21: 17.025938 kN
#   Member 26: 24.260963 kN
#   Member 42: -14.099124 kN
#   Member 41: -7.936325 kN
# --------------------------------------------------
# Generation 4: New Best Volume = 593.669053 cubic units
# Current Fixed Member Forces:
#   Member 34: 11.448870 kN
#   Member 33: 16.663542 kN
#   Member 21: -28.217791 kN
#   Member 26: 1.744732 kN
#   Member 42: -17.981415 kN
#   Member 41: 5.111558 kN
# --------------------------------------------------
# Generation 5: New Best Volume = 415.665796 cubic units
# Current Fixed Member Forces:
#   Member 34: 8.773679 kN
#   Member 33: 18.489392 kN
#   Member 21: -5.277886 kN
#   Member 26: 15.034881 kN
#   Member 42: -21.644584 kN
#   Member 41: -3.949603 kN
# --------------------------------------------------
# Generation 7: New Best Volume = 395.157863 cubic units
# Current Fixed Member Forces:
#   Member 34: 10.161503 kN
#   Member 33: 19.240507 kN
#   Member 21: -2.469977 kN
#   Member 26: 22.552818 kN
#   Member 42: -18.770141 kN
#   Member 41: -12.276649 kN
# --------------------------------------------------
# Generation 9: New Best Volume = 378.817510 cubic units
# Current Fixed Member Forces:
#   Member 34: -2.270403 kN
#   Member 33: 23.299297 kN
#   Member 21: -1.463951 kN
#   Member 26: 14.995279 kN
#   Member 42: -22.870691 kN
#   Member 41: 1.211723 kN
# --------------------------------------------------
# Generation 12: New Best Volume = 374.899124 cubic units
# Current Fixed Member Forces:
#   Member 34: -2.270403 kN
#   Member 33: 23.299297 kN
#   Member 21: -1.463951 kN
#   Member 26: 19.357197 kN
#   Member 42: -17.365310 kN
#   Member 41: -7.757639 kN
# --------------------------------------------------
# Generation 13: New Best Volume = 366.064559 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.394301 kN
#   Member 33: 23.299297 kN
#   Member 21: -1.463951 kN
#   Member 26: 17.379656 kN
#   Member 42: -16.686087 kN
#   Member 41: -0.422964 kN
# --------------------------------------------------
# Generation 16: New Best Volume = 364.123443 cubic units
# Current Fixed Member Forces:
#   Member 34: 3.631819 kN
#   Member 33: 20.166601 kN
#   Member 21: 1.247323 kN
#   Member 26: 20.335604 kN
#   Member 42: -22.677441 kN
#   Member 41: -5.034354 kN
# --------------------------------------------------
# Generation 20: New Best Volume = 359.981953 cubic units
# Current Fixed Member Forces:
#   Member 34: 3.631819 kN
#   Member 33: 20.166601 kN
#   Member 21: 1.247323 kN
#   Member 26: 20.335604 kN
#   Member 42: -20.620751 kN
#   Member 41: -5.034354 kN
# --------------------------------------------------
# Generation 59: New Best Volume = 359.455453 cubic units
# Current Fixed Member Forces:
#   Member 34: 3.631819 kN
#   Member 33: 20.166601 kN
#   Member 21: 0.960819 kN
#   Member 26: 20.136849 kN
#   Member 42: -20.620751 kN
#   Member 41: -5.034354 kN
# --------------------------------------------------
# Generation 62: New Best Volume = 350.896686 cubic units
# Current Fixed Member Forces:
#   Member 34: 4.697956 kN
#   Member 33: 19.472550 kN
#   Member 21: -2.564765 kN
#   Member 26: 20.136849 kN
#   Member 42: -20.978627 kN
#   Member 41: -0.058728 kN
# --------------------------------------------------
# Generation 110: New Best Volume = 350.867649 cubic units
# Current Fixed Member Forces:
#   Member 34: 3.104723 kN
#   Member 33: 19.472550 kN
#   Member 21: -2.564765 kN
#   Member 26: 20.136849 kN
#   Member 42: -21.965227 kN
#   Member 41: 0.259115 kN
# --------------------------------------------------
# Generation 115: New Best Volume = 345.429025 cubic units
# Current Fixed Member Forces:
#   Member 34: 3.104723 kN
#   Member 33: 19.472550 kN
#   Member 21: -0.857942 kN
#   Member 26: 20.136849 kN
#   Member 42: -21.965227 kN
#   Member 41: 0.259115 kN
# --------------------------------------------------
# Generation 198: New Best Volume = 344.306014 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.435300 kN
#   Member 33: 20.428377 kN
#   Member 21: -0.857942 kN
#   Member 26: 20.136849 kN
#   Member 42: -21.965227 kN
#   Member 41: 0.259115 kN
# --------------------------------------------------
# Generation 206: New Best Volume = 339.986817 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.750729 kN
#   Member 33: 20.920451 kN
#   Member 21: -0.857942 kN
#   Member 26: 20.136849 kN
#   Member 42: -21.965227 kN
#   Member 41: 0.259115 kN
# --------------------------------------------------
# Generation 216: New Best Volume = 337.015121 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.750729 kN
#   Member 33: 20.920451 kN
#   Member 21: -0.857942 kN
#   Member 26: 20.136849 kN
#   Member 42: -20.842265 kN
#   Member 41: -0.715811 kN
# --------------------------------------------------
# Generation 314: New Best Volume = 336.823994 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.502730 kN
#   Member 33: 20.920451 kN
#   Member 21: -0.857942 kN
#   Member 26: 20.136849 kN
#   Member 42: -20.842265 kN
#   Member 41: -0.715811 kN
# --------------------------------------------------
# Generation 322: New Best Volume = 335.333092 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.502730 kN
#   Member 33: 21.560831 kN
#   Member 21: -0.575838 kN
#   Member 26: 20.136849 kN
#   Member 42: -20.842265 kN
#   Member 41: -0.715811 kN
# --------------------------------------------------
# Generation 428: New Best Volume = 335.221277 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.965847 kN
#   Member 33: 20.543176 kN
#   Member 21: -0.150929 kN
#   Member 26: 19.698801 kN
#   Member 42: -20.842265 kN
#   Member 41: 0.016009 kN
# --------------------------------------------------
# Generation 441: New Best Volume = 335.156177 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.049767 kN
#   Member 33: 20.543176 kN
#   Member 21: -0.534061 kN
#   Member 26: 19.698801 kN
#   Member 42: -20.744266 kN
#   Member 41: -0.481106 kN
# --------------------------------------------------
# Generation 449: New Best Volume = 334.482859 cubic units
# Current Fixed Member Forces:
#   Member 34: 2.076732 kN
#   Member 33: 20.869507 kN
#   Member 21: -0.175133 kN
#   Member 26: 20.870645 kN
#   Member 42: -21.170264 kN
#   Member 41: -1.425715 kN
# --------------------------------------------------
# Generation 454: New Best Volume = 333.505170 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.995900 kN
#   Member 33: 21.464617 kN
#   Member 21: -0.175133 kN
#   Member 26: 20.870645 kN
#   Member 42: -21.170264 kN
#   Member 41: -1.316459 kN
# --------------------------------------------------
# Generation 464: New Best Volume = 333.263063 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.956940 kN
#   Member 33: 21.292102 kN
#   Member 21: -0.278537 kN
#   Member 26: 20.684341 kN
#   Member 42: -21.091343 kN
#   Member 41: -1.353884 kN
# --------------------------------------------------
# Generation 472: New Best Volume = 332.873154 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.135483 kN
#   Member 33: 21.721870 kN
#   Member 21: -0.007163 kN
#   Member 26: 20.382767 kN
#   Member 42: -21.434499 kN
#   Member 41: -0.468689 kN
# --------------------------------------------------
# Generation 474: New Best Volume = 332.581186 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.137254 kN
#   Member 33: 21.237537 kN
#   Member 21: -0.122558 kN
#   Member 26: 20.162975 kN
#   Member 42: -21.051703 kN
#   Member 41: -0.272946 kN
# --------------------------------------------------
# Generation 475: New Best Volume = 332.185040 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.187062 kN
#   Member 33: 21.430056 kN
#   Member 21: 0.136977 kN
#   Member 26: 20.103682 kN
#   Member 42: -21.158948 kN
#   Member 41: -0.158041 kN
# --------------------------------------------------
# Generation 487: New Best Volume = 332.101748 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.274525 kN
#   Member 33: 21.107767 kN
#   Member 21: -0.004666 kN
#   Member 26: 20.103682 kN
#   Member 42: -21.663984 kN
#   Member 41: -0.158041 kN
# --------------------------------------------------
# Generation 488: New Best Volume = 332.024590 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.238508 kN
#   Member 33: 21.560123 kN
#   Member 21: 0.008995 kN
#   Member 26: 20.330200 kN
#   Member 42: -21.173421 kN
#   Member 41: -0.457285 kN
# --------------------------------------------------
# Generation 489: New Best Volume = 331.609843 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.183587 kN
#   Member 33: 21.211261 kN
#   Member 21: -0.004666 kN
#   Member 26: 20.103682 kN
#   Member 42: -21.663984 kN
#   Member 41: -0.158041 kN
# --------------------------------------------------
# Generation 490: New Best Volume = 331.595339 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.240416 kN
#   Member 33: 21.002560 kN
#   Member 21: 0.000713 kN
#   Member 26: 20.006771 kN
#   Member 42: -21.158948 kN
#   Member 41: -0.035893 kN
# --------------------------------------------------
# Generation 491: New Best Volume = 331.583314 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.332299 kN
#   Member 33: 21.230323 kN
#   Member 21: 0.008995 kN
#   Member 26: 20.146508 kN
#   Member 42: -21.520807 kN
#   Member 41: -0.166341 kN
# --------------------------------------------------
# Generation 493: New Best Volume = 331.098619 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.321116 kN
#   Member 33: 21.110686 kN
#   Member 21: -0.068967 kN
#   Member 26: 20.030690 kN
#   Member 42: -21.144317 kN
#   Member 41: -0.179491 kN
# --------------------------------------------------
# Generation 494: New Best Volume = 330.883263 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.170256 kN
#   Member 33: 21.086234 kN
#   Member 21: -0.068967 kN
#   Member 26: 19.943004 kN
#   Member 42: -21.263081 kN
#   Member 41: -0.014035 kN
# --------------------------------------------------
# Generation 495: New Best Volume = 330.837076 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.197748 kN
#   Member 33: 21.299227 kN
#   Member 21: 0.027687 kN
#   Member 26: 20.158460 kN
#   Member 42: -21.186965 kN
#   Member 41: -0.289589 kN
# --------------------------------------------------
# Generation 496: New Best Volume = 330.748086 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.156173 kN
#   Member 33: 21.182020 kN
#   Member 21: -0.044754 kN
#   Member 26: 19.985132 kN
#   Member 42: -21.279360 kN
#   Member 41: -0.032110 kN
# --------------------------------------------------
# Generation 499: New Best Volume = 330.656218 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.085717 kN
#   Member 33: 21.200149 kN
#   Member 21: -0.091927 kN
#   Member 26: 19.952909 kN
#   Member 42: -21.218560 kN
#   Member 41: -0.106042 kN
# --------------------------------------------------
# Generation 500: New Best Volume = 330.505159 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.156173 kN
#   Member 33: 21.202511 kN
#   Member 21: -0.044754 kN
#   Member 26: 20.015858 kN
#   Member 42: -21.188580 kN
#   Member 41: -0.087713 kN
# --------------------------------------------------
#
# --- Optimization Results ---
#
# Optimized Fixed Member Forces:
#   Member 34: 0.156173 kN
#   Member 33: 21.202511 kN
#   Member 21: -0.044754 kN
#   Member 26: 20.015858 kN
#   Member 42: -21.188580 kN
#   Member 41: -0.087713 kN
#
# Minimum Structure Volume Achieved: 330.505159 cubic units

# %% [markdown]
# ## Colour of bars switch

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.colors import LinearSegmentedColormap
import random
import copy

# ------------------------- Configuration -------------------------

USE_SEED = False  # Set to False to disable fixed random seed

# New Configuration Options
SPECIFY_FIXED_MEMBERS = True  # Set to True to specify fixed members manually
SPECIFIED_FIXED_MEMBER_IDS = [34, 33, 21, 26, 42, 41]  # List of member IDs to fix

# Truss Configuration
COLUMNS = 7  # Number of columns of nodes
ROWS = 3     # Number of rows of nodes

# Load Nodes: {node_id: [Fx, Fy], ...}
# Nodes 3, 6, 9, 12, 15, 18, 21 have a load of [0, -10]
LOAD_NODES = {
    3: [0, -10],
    6: [0, -10],
    9: [0, -10],
    12: [0, -10],
    15: [0, -10],
    18: [0, -10],
    21: [0, -10]
}

# Support Nodes: {node_id: [Restrain_x (1 or 0), Restrain_y (1 or 0)], ...}
# Nodes 1 and 19 are supports restrained in x and y
SUPPORT_NODES = {
    1: [1, 1],
    19: [1, 1]
}

# ------------------------- Part 1: Truss Definition -------------------------

class Truss:
    def __init__(self, columns=COLUMNS, rows=ROWS, load_nodes=LOAD_NODES, support_nodes=SUPPORT_NODES):
        self.columns = columns
        self.rows = rows
        self.nodes = {}
        self.members = {}
        self.external_loads = load_nodes  # {node_id: [Fx, Fy], ...}
        self.support_nodes = support_nodes  # {node_id: [Restrain_x, Restrain_y], ...}
        self.support_reactions = {}  # Will be populated based on support_nodes
        self.fixed_member_ids = []  # To be set dynamically based on degree of indeterminacy
        self.degree_of_indeterminacy = 0
        self.direction_cosines_cache = {}
        self.initialize_truss()

    def initialize_truss(self):
        self.define_nodes()
        self.define_members()
        self.define_support_reactions()
        self.compute_degree_of_indeterminacy()

    def define_nodes(self):
        node_id = 1
        for x in range(self.columns):       # x=0 to x=COLUMNS-1
            for y in range(self.rows):      # y=0 to y=ROWS-1
                self.nodes[node_id] = (x, y)
                node_id += 1

    def add_member(self, start, end):
        if start not in self.nodes or end not in self.nodes:
            print(f"Skipping member ({start}, {end}) - Invalid node number.")
            return
        # Avoid duplicate members
        if not any(
            (start == existing_start and end == existing_end) or
            (start == existing_end and end == existing_start)
            for existing_start, existing_end in self.members.values()
        ):
            self.members[len(self.members) + 1] = (start, end)

    def define_members(self):
        # Add vertical members
        for x in range(self.columns):
            for y in range(self.rows - 1):
                node_start = x * self.rows + y + 1
                node_end = node_start + 1
                self.add_member(node_start, node_end)

        # Add horizontal members
        for x in range(self.columns - 1):
            for y in range(self.rows):
                node_start = x * self.rows + y + 1
                node_end = (x + 1) * self.rows + y + 1
                self.add_member(node_start, node_end)

        # Add diagonal members at special nodes
        for x in range(self.columns):
            for y in range(self.rows):
                # Identify special nodes (every second node in every second column)
                if x % 2 == 1 and y % 2 == 1:
                    current_node = x * self.rows + y + 1
                    # Top-right diagonal
                    if x < self.columns - 1 and y < self.rows - 1:
                        node_tr = (x + 1) * self.rows + y + 2
                        self.add_member(current_node, node_tr)
                    # Top-left diagonal
                    if x > 0 and y < self.rows - 1:
                        node_tl = (x - 1) * self.rows + y + 2
                        self.add_member(current_node, node_tl)
                    # Bottom-left diagonal
                    if x > 0 and y > 0:
                        node_bl = (x - 1) * self.rows + y
                        self.add_member(current_node, node_bl)
                    # Bottom-right diagonal
                    if x < self.columns - 1 and y > 0:
                        node_br = (x + 1) * self.rows + y
                        self.add_member(current_node, node_br)

    def find_node(self, x, y):
        for nid, coord in self.nodes.items():
            if coord == (x, y):
                return nid
        return None

    def define_support_reactions(self):
        # For each support node, define reactions based on restraints
        self.support_reactions = {}
        for node_id, restraints in self.support_nodes.items():
            restrain_x, restrain_y = restraints
            if restrain_x:
                self.support_reactions[f'R{node_id}x'] = None
            if restrain_y:
                self.support_reactions[f'R{node_id}y'] = None

    def compute_degree_of_indeterminacy(self):
        num_reactions = len(self.support_reactions)
        num_members = len(self.members)
        num_nodes = len(self.nodes)
        self.degree_of_indeterminacy = num_members + num_reactions - 2 * num_nodes

    def direction_cosines(self, start, end):
        key = tuple(sorted((start, end)))
        if key in self.direction_cosines_cache:
            return self.direction_cosines_cache[key]
        x1, y1 = self.nodes[start]
        x2, y2 = self.nodes[end]
        delta_x = x2 - x1
        delta_y = y2 - y1
        length = np.sqrt(delta_x**2 + delta_y**2)
        if length == 0:
            raise ValueError(f"Zero length member between nodes {start} and {end}.")
        cos_theta = delta_x / length
        sin_theta = delta_y / length
        self.direction_cosines_cache[key] = (cos_theta, sin_theta)
        return cos_theta, sin_theta

# ------------------------- Part 2: Genetic Algorithm for Minimum Truss Volume -------------------------

class GeneticAlgorithmOptimizer:
    def __init__(self, truss, seed_fixed_member_ids, seed_fixed_forces,
                 material_stress=1, population_size=200, generations=200,
                 tournament_size=3, crossover_rate=0.8, mutation_rate=0.5, mutation_amount=10, elitism=True):
        self.truss = truss
        self.seed_fixed_member_ids = seed_fixed_member_ids
        self.seed_fixed_forces = seed_fixed_forces
        self.material_stress = material_stress

        # Genetic Algorithm Parameters
        self.POPULATION_SIZE = population_size
        self.GENERATIONS = generations
        self.TOURNAMENT_SIZE = tournament_size
        self.CROSSOVER_RATE = crossover_rate
        self.MUTATION_RATE = mutation_rate
        self.MUTATION_AMOUNT = mutation_amount
        self.elitism = elitism

        # Define gene bounds (-50 to 50)
        self.gene_bounds = [(-50, 50) for _ in self.seed_fixed_forces]

        # Create mappings
        self.fixed_member_indices = [m - 1 for m in self.seed_fixed_member_ids]
        self.unknown_member_indices = [
            i for i in range(len(truss.members)) if i not in self.fixed_member_indices
        ]
        self.num_reactions = len(truss.support_reactions)
        self.num_members = len(truss.members)
        self.num_unknowns_ga = len(self.unknown_member_indices) + self.num_reactions

        # Mapping from member index to unknown index
        self.member_index_to_unknown = {
            i: idx for idx, i in enumerate(self.unknown_member_indices)
        }

        # Mapping for reaction indices
        self.reaction_indices = {}
        for idx, reaction in enumerate(self.truss.support_reactions):
            self.reaction_indices[reaction] = len(self.unknown_member_indices) + idx

    def initialize_population(self):
        population = []
        for _ in range(self.POPULATION_SIZE):
            individual = [
                random.uniform(low, high) for (low, high) in self.gene_bounds
            ]
            population.append(individual)
        return population

    def compute_total_volume(self, current_fixed_member_forces):
        A_ga, B_ga = self.setup_equilibrium(current_fixed_member_forces)
        try:
            F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
            equilibrium_satisfied_ga = True
        except np.linalg.LinAlgError:
            F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)
            equilibrium_satisfied_ga = False

        # Check equilibrium
        B_calculated = np.dot(A_ga, F_unknowns_ga)
        difference = B_calculated - B_ga
        tolerance = 1e-5  # Adjust tolerance as needed
        if np.any(np.abs(difference) > tolerance):
            # Equilibrium not satisfied, return a large fitness value
            return 1e10  # Large penalty
        else:
            # Reconstruct full member forces
            F_full_ga = np.zeros(self.num_members)
            for member_index in self.unknown_member_indices:
                unknown_idx = self.member_index_to_unknown[member_index]
                F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
            for i, m_id in enumerate(self.seed_fixed_member_ids):
                F_full_ga[m_id - 1] = current_fixed_member_forces[m_id]

            # Calculate total volume
            total_volume = 0.0
            for m_id, (start, end) in self.truss.members.items():
                x1, y1 = self.truss.nodes[start]
                x2, y2 = self.truss.nodes[end]
                length = np.sqrt((x2 - x1)**2 + (y2 - y1)**2)
                force_magnitude = abs(F_full_ga[m_id - 1])
                cross_sectional_area = force_magnitude / self.material_stress
                volume = cross_sectional_area * length
                total_volume += volume

            return total_volume

    def setup_equilibrium(self, current_fixed_member_forces):
        num_members = self.num_members
        num_reactions = self.num_reactions
        num_nodes = len(self.truss.nodes)
        equations_per_node = 2
        total_equations = num_nodes * equations_per_node
        total_unknowns = self.num_unknowns_ga

        A_ga = np.zeros((total_equations, total_unknowns))
        B_ga = np.zeros(total_equations)

        # Map reactions to indices
        reaction_indices = self.reaction_indices

        for node in self.truss.nodes:
            eq_x = (node - 1) * 2
            eq_y = eq_x + 1

            # Assign external loads
            load = self.truss.external_loads.get(node, [0, 0])
            B_ga[eq_x] += load[0]
            B_ga[eq_y] += load[1]

            # Iterate through connected members
            for m_id, (start, end) in self.truss.members.items():
                member_index = m_id - 1
                if node == start or node == end:
                    other = end if node == start else start
                    cos_theta, sin_theta = self.truss.direction_cosines(node, other)
                    coef_x = cos_theta if node == start else -cos_theta
                    coef_y = sin_theta if node == start else -sin_theta

                    if m_id in current_fixed_member_forces:
                        fixed_force = current_fixed_member_forces[m_id]
                        B_ga[eq_x] -= coef_x * fixed_force
                        B_ga[eq_y] -= coef_y * fixed_force
                    else:
                        if member_index in self.member_index_to_unknown:
                            unknown_idx = self.member_index_to_unknown[member_index]
                            A_ga[eq_x, unknown_idx] += coef_x
                            A_ga[eq_y, unknown_idx] += coef_y

            # Assign support reactions
            if node in self.truss.support_nodes:
                restraints = self.truss.support_nodes[node]
                restrain_x, restrain_y = restraints
                if restrain_x:
                    reaction_name = f'R{node}x'
                    A_ga[eq_x, reaction_indices[reaction_name]] -= 1
                if restrain_y:
                    reaction_name = f'R{node}y'
                    A_ga[eq_y, reaction_indices[reaction_name]] -= 1

        return A_ga, B_ga

    def fitness(self, individual):
        current_fixed_member_forces = {
            m: individual[i] for i, m in enumerate(self.seed_fixed_member_ids)
        }
        total_vol = self.compute_total_volume(current_fixed_member_forces)
        return total_vol  # Objective: minimize total volume

    def tournament_selection(self, population, scores):
        selected = []
        for _ in range(self.POPULATION_SIZE):
            aspirants = random.sample(range(len(population)), self.TOURNAMENT_SIZE)
            aspirant_scores = [scores[i] for i in aspirants]
            winner = aspirants[np.argmin(aspirant_scores)]
            selected.append(copy.deepcopy(population[winner]))
        return selected

    def mutate(self, individual, generation):
        # Adaptive mutation amount: decreases over generations
        adaptive_mutation_amount = self.MUTATION_AMOUNT * (1 - generation / self.GENERATIONS)
        for i in range(len(individual)):
            if random.random() < self.MUTATION_RATE:
                mutation = random.uniform(-adaptive_mutation_amount, adaptive_mutation_amount)
                individual[i] += mutation
                # Clamp the gene within bounds
                low, high = self.gene_bounds[i]
                individual[i] = max(low, min(individual[i], high))
        return individual

    def run(self):
        population = self.initialize_population()
        best_volume = float('inf')
        best_individual = None

        for gen in range(1, self.GENERATIONS + 1):
            # Evaluate fitness
            scores = [self.fitness(ind) for ind in population]
            # Find the best individual in current generation
            min_score = min(scores)
            min_index = scores.index(min_score)
            current_best_individual = population[min_index]
            current_best_volume = min_score

            # Update global best
            if current_best_volume < best_volume:
                best_volume = current_best_volume
                best_individual = copy.deepcopy(current_best_individual)
                print(f"Generation {gen}: New Best Volume = {best_volume:.6f} cubic units")
                print("Current Fixed Member Forces:")
                for i, m in enumerate(self.seed_fixed_member_ids):
                    print(f"  Member {m}: {best_individual[i]:.6f} kN")
                print("-" * 50)

            # Selection
            selected = self.tournament_selection(population, scores)

            # Crossover and Mutation
            next_generation = []

            # Elitism: carry over the best individual
            if self.elitism:
                next_generation.append(best_individual)

            while len(next_generation) < self.POPULATION_SIZE:
                parent1 = random.choice(selected)
                parent2 = random.choice(selected)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1, gen)
                child2 = self.mutate(child2, gen)
                next_generation.extend([child1, child2])

            population = next_generation[:self.POPULATION_SIZE]

        return best_individual, best_volume

    def crossover(self, parent1, parent2):
        if random.random() < self.CROSSOVER_RATE:
            point = random.randint(1, len(parent1) - 1)
            child1 = parent1[:point] + parent2[point:]
            child2 = parent2[:point] + parent1[point:]
            return child1, child2
        return copy.deepcopy(parent1), copy.deepcopy(parent2)

# ------------------------- Part 3: Visualization of Truss -------------------------

def visualize_truss(truss, fixed_member_forces, title="Truss Structure"):
    """
    Visualize the truss structure with member forces and Member IDs.
    """
    # Setup equilibrium with given fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(fixed_member_forces.keys()),
        seed_fixed_forces=fixed_member_forces,
        material_stress=1  # Assuming material_stress is 1 for consistency
    )

    A_ga, B_ga = optimizer.setup_equilibrium(fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = fixed_member_forces[m_id]

    # Plot the Truss
    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Define colors for different member statuses
    tension_color = 'blue'
    compression_color = 'red'
    zero_color = 'gray'
    fixed_color = 'green'

    # Plot each member
    for m_id, (start, end) in truss.members.items():
        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        force = F_full_ga[m_id - 1]

        # Determine color based on force
        if m_id in optimizer.seed_fixed_member_ids:
            color = fixed_color
            linewidth = 2
        else:
            # Swap the interpretation: Positive = Compression, Negative = Tension
            if force > 0:
                color = compression_color  # Previously tension_color
                linewidth = 2
            elif force < 0:
                color = tension_color  # Previously compression_color
                linewidth = 2
            else:
                color = zero_color
                linewidth = 1

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=linewidth)

        # Annotate the force value at the midpoint
        x_mid = (x_start + x_end) / 2
        y_mid = (y_start + y_end) / 2
        if force != 0:
            plt.text(x_mid, y_mid, f"{force:.1f}kN",
                     color='black', fontsize=8, ha='center', va='center')

        # Annotate the Member ID slightly offset from the midpoint
        offset = 0.1  # Adjust as needed for clarity
        plt.text(x_mid + offset, y_mid + offset, f"ID:{m_id}",
                 color='purple', fontsize=8, ha='center', va='center')

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Plot supports
    support_plotted = False
    for node_id, restraints in truss.support_nodes.items():
        x, y = truss.nodes[node_id]
        plt.plot(x, y, marker='^', markersize=10, markerfacecolor='black',
                 label='Support' if not support_plotted else "")
        support_plotted = True

    # Create custom legend
    tension_patch = mpatches.Patch(color=tension_color, label='Tension')  # Now correctly represents negative forces
    compression_patch = mpatches.Patch(color=compression_color, label='Compression')  # Now correctly represents positive forces
    zero_patch = mpatches.Patch(color=zero_color, label='Zero-force')
    fixed_patch = mpatches.Patch(color=fixed_color, label='Fixed Force')
    handles = [tension_patch, compression_patch, zero_patch, fixed_patch]
    if support_plotted:
        pin_patch = Line2D([0], [0], marker='^', color='w', label='Support',
                           markerfacecolor='black', markersize=10)
        handles.append(pin_patch)
    plt.legend(handles=handles, loc='upper right')

    plt.grid(True)
    plt.show()

def plot_cross_section_colored_truss(truss, fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections"):
    """
    Plot the truss with cross-sectional areas colored based on normalized values.
    """
    # Setup equilibrium with given fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(fixed_member_forces.keys()),
        seed_fixed_forces=fixed_member_forces,
        material_stress=material_stress
    )

    A_ga, B_ga = optimizer.setup_equilibrium(fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = fixed_member_forces[m_id]

    # Calculate cross-sectional areas and exclude members with zero force or force <1kN
    cross_sections = {}
    for m_id, force in zip(range(1, num_members + 1), F_full_ga):
        if force != 0 and abs(force) >= 1:
            cross_sections[m_id] = abs(force) / material_stress

    if not cross_sections:
        print("No members with non-zero force >= 1kN to plot.")
        return

    # Normalize cross-sectional areas for color mapping
    min_cs = min(cross_sections.values())
    max_cs = max(cross_sections.values())
    if max_cs != min_cs:
        normalized_cs = {m_id: (cs - min_cs) / (max_cs - min_cs) for m_id, cs in cross_sections.items()}
    else:
        normalized_cs = {m_id: 0.5 for m_id in cross_sections}  # All same color

    # Create a custom "dark rainbow" colormap reversed: dark blue to red
    dark_rainbow = LinearSegmentedColormap.from_list('dark_rainbow', ['darkblue', 'lightblue', 'green', 'yellow', 'orange', 'red'])

    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Plot each member with color based on normalized cross-section
    for m_id, (start, end) in truss.members.items():
        if m_id not in cross_sections:
            continue  # Skip members with zero force or force <1kN

        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        normalized_value = normalized_cs[m_id]
        color = dark_rainbow(normalized_value)

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=2)

        # Annotate the Member ID slightly offset from the midpoint
        x_mid = (x_start + x_end) / 2
        y_mid = (y_start + y_end) / 2
        offset = 0.1  # Adjust as needed for clarity
        plt.text(x_mid + offset, y_mid + offset, f"ID:{m_id}",
                 color='purple', fontsize=8, ha='center', va='center')

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Plot supports
    support_plotted = False
    for node_id, restraints in truss.support_nodes.items():
        x, y = truss.nodes[node_id]
        plt.plot(x, y, marker='^', markersize=10, markerfacecolor='black',
                 label='Support' if not support_plotted else "")
        support_plotted = True

    # Create a colorbar
    sm = plt.cm.ScalarMappable(cmap=dark_rainbow, norm=plt.Normalize(vmin=min_cs, vmax=max_cs))
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, shrink=0.6)
    cbar.set_label('Cross-Sectional Area (normalized)')

    # Create custom legend for supports
    handles = []
    tension_patch = mpatches.Patch(color='blue', label='Tension')
    compression_patch = mpatches.Patch(color='red', label='Compression')
    zero_patch = mpatches.Patch(color='gray', label='Zero-force')
    fixed_patch = mpatches.Patch(color='green', label='Fixed Force')
    handles.extend([tension_patch, compression_patch, zero_patch, fixed_patch])
    if support_plotted:
        pin_patch = Line2D([0], [0], marker='^', color='w', label='Support',
                           markerfacecolor='black', markersize=10)
        handles.append(pin_patch)
    plt.legend(handles=handles, loc='upper right')

    plt.grid(True)
    plt.show()

# ------------------------- Utility Function -------------------------

def select_random_fixed_members(truss, N):
    total_members = len(truss.members)
    if N > total_members:
        raise ValueError(f"Cannot select {N} members as there are only {total_members} members.")
    fixed_member_ids = random.sample(range(1, total_members + 1), N)
    return fixed_member_ids

# ------------------------- Main Execution -------------------------

if __name__ == "__main__":
    # Set random seeds for reproducibility (optional)
    if USE_SEED:
        random.seed(42)
        np.random.seed(42)
        print("Random seeds are set for reproducibility.\n")
    else:
        print("Random seeds are not set. Results may vary with each run.\n")

    # Initialize the truss
    truss = Truss()

    # Compute degree of indeterminacy
    truss.compute_degree_of_indeterminacy()
    print(f"Degree of Indeterminacy: {truss.degree_of_indeterminacy}\n")

    # Determine fixed members based on user configuration
    N = truss.degree_of_indeterminacy
    if SPECIFY_FIXED_MEMBERS:
        if len(SPECIFIED_FIXED_MEMBER_IDS) != N:
            print(f"Error: Number of specified fixed members ({len(SPECIFIED_FIXED_MEMBER_IDS)}) does not match the degree of indeterminacy ({N}).")
            exit(1)
        fixed_member_ids = SPECIFIED_FIXED_MEMBER_IDS
    else:
        fixed_member_ids = select_random_fixed_members(truss, N)

    # Assign the fixed_member_ids to the truss
    truss.fixed_member_ids = fixed_member_ids

    # Generate random initial forces for the fixed members between -50 and 50
    seed_fixed_forces = {m_id: random.uniform(-50, 50) for m_id in fixed_member_ids}

    # Print selected fixed members and their initial random forces
    print("--- Genetic Algorithm Optimization ---\n")
    print(f"Selected Fixed Members (Total {N}):")
    for m_id, force in seed_fixed_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print("\nVisualizing Initial Truss Structure...\n")

    # Visualize the initial truss before optimization
    visualize_truss(truss, seed_fixed_forces, title="Initial Truss Structure")

    print("\nStarting Genetic Algorithm...\n")

    # Initialize and run the genetic algorithm optimizer
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=fixed_member_ids,
        seed_fixed_forces=seed_fixed_forces,
        material_stress=1,          # Adjust based on material properties
        population_size=200,        # Increased population size for diversity
        generations=500,            # Increased number of generations
        tournament_size=3,          # Number of individuals competing in tournament selection
        crossover_rate=0.8,         # Probability of crossover
        mutation_rate=0.5,          # Increased mutation rate
        mutation_amount=20,         # Increased mutation amount
        elitism=True                # Use elitism to preserve the best individual
    )

    best_individual, best_volume = optimizer.run()

    # Map the best individual to fixed member forces
    optimized_fixed_member_forces = {m_id: best_individual[i] for i, m_id in enumerate(fixed_member_ids)}

    # Print optimization results
    print("\n--- Optimization Results ---\n")
    print("Optimized Fixed Member Forces:")
    for m_id, force in optimized_fixed_member_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print(f"\nMinimum Structure Volume Achieved: {best_volume:.6f} cubic units\n")

    # Visualize the optimized truss
    visualize_truss(truss, optimized_fixed_member_forces, title="Optimized Truss Structure with Minimized Volume")

    # Plot the cross-section normalized truss
    plot_cross_section_colored_truss(truss, optimized_fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections")
# Out:
# Random seeds are not set. Results may vary with each run.
#
# Degree of Indeterminacy: 6
#
# --- Genetic Algorithm Optimization ---
#
# Selected Fixed Members (Total 6):
#   Member 34: -29.158558 kN
#   Member 33: 30.119312 kN
#   Member 21: 24.576972 kN
#   Member 26: -17.104625 kN
#   Member 42: -14.546618 kN
#   Member 41: 8.880176 kN
#
# Visualizing Initial Truss Structure...
# Starting Genetic Algorithm...
#
# Generation 1: New Best Volume = 505.344400 cubic units
# Current Fixed Member Forces:
#   Member 34: -5.514236 kN
#   Member 33: 24.120074 kN
#   Member 21: 3.364582 kN
#   Member 26: 26.294350 kN
#   Member 42: -34.552461 kN
#   Member 41: 2.372646 kN
# --------------------------------------------------
# Generation 3: New Best Volume = 473.337570 cubic units
# Current Fixed Member Forces:
#   Member 34: -6.683886 kN
#   Member 33: 24.120074 kN
#   Member 21: 3.364582 kN
#   Member 26: 19.964246 kN
#   Member 42: -34.552461 kN
#   Member 41: 2.370990 kN
# --------------------------------------------------
# Generation 4: New Best Volume = 441.770710 cubic units
# Current Fixed Member Forces:
#   Member 34: -3.063318 kN
#   Member 33: 28.672596 kN
#   Member 21: 3.364582 kN
#   Member 26: 19.964246 kN
#   Member 42: -34.552461 kN
#   Member 41: 6.625272 kN
# --------------------------------------------------
# Generation 5: New Best Volume = 419.852250 cubic units
# Current Fixed Member Forces:
#   Member 34: 6.932454 kN
#   Member 33: 17.013717 kN
#   Member 21: -8.706283 kN
#   Member 26: 15.828541 kN
#   Member 42: -15.718987 kN
#   Member 41: 2.370990 kN
# --------------------------------------------------
# Generation 6: New Best Volume = 394.250756 cubic units
# Current Fixed Member Forces:
#   Member 34: -3.063318 kN
#   Member 33: 28.672596 kN
#   Member 21: 3.364582 kN
#   Member 26: 19.964246 kN
#   Member 42: -24.193630 kN
#   Member 41: -1.999732 kN
# --------------------------------------------------
# Generation 7: New Best Volume = 393.483901 cubic units
# Current Fixed Member Forces:
#   Member 34: 6.910777 kN
#   Member 33: 22.127204 kN
#   Member 21: 4.644832 kN
#   Member 26: 27.350980 kN
#   Member 42: -20.875253 kN
#   Member 41: -7.180358 kN
# --------------------------------------------------
# Generation 10: New Best Volume = 386.707300 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.957571 kN
#   Member 33: 16.533424 kN
#   Member 21: -8.638259 kN
#   Member 26: 13.071422 kN
#   Member 42: -15.527178 kN
#   Member 41: 1.683409 kN
# --------------------------------------------------
# Generation 15: New Best Volume = 375.081425 cubic units
# Current Fixed Member Forces:
#   Member 34: 4.686039 kN
#   Member 33: 23.644410 kN
#   Member 21: 2.662225 kN
#   Member 26: 21.881739 kN
#   Member 42: -21.104638 kN
#   Member 41: -7.073426 kN
# --------------------------------------------------
# Generation 34: New Best Volume = 359.752862 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.246432 kN
#   Member 33: 22.135828 kN
#   Member 21: -2.505582 kN
#   Member 26: 16.843237 kN
#   Member 42: -17.397911 kN
#   Member 41: -3.425377 kN
# --------------------------------------------------
# Generation 58: New Best Volume = 356.169354 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.246432 kN
#   Member 33: 22.135828 kN
#   Member 21: -4.145376 kN
#   Member 26: 16.843237 kN
#   Member 42: -17.397911 kN
#   Member 41: -2.685693 kN
# --------------------------------------------------
# Generation 123: New Best Volume = 355.429638 cubic units
# Current Fixed Member Forces:
#   Member 34: -1.128285 kN
#   Member 33: 22.488356 kN
#   Member 21: -0.187301 kN
#   Member 26: 17.926539 kN
#   Member 42: -18.586413 kN
#   Member 41: -0.571375 kN
# --------------------------------------------------
# Generation 124: New Best Volume = 350.480203 cubic units
# Current Fixed Member Forces:
#   Member 34: -1.128285 kN
#   Member 33: 22.488356 kN
#   Member 21: -0.187301 kN
#   Member 26: 17.926539 kN
#   Member 42: -19.947238 kN
#   Member 41: -0.571375 kN
# --------------------------------------------------
# Generation 169: New Best Volume = 350.418491 cubic units
# Current Fixed Member Forces:
#   Member 34: 2.456838 kN
#   Member 33: 19.041663 kN
#   Member 21: -3.115533 kN
#   Member 26: 18.822608 kN
#   Member 42: -19.414793 kN
#   Member 41: -3.962312 kN
# --------------------------------------------------
# Generation 184: New Best Volume = 349.974432 cubic units
# Current Fixed Member Forces:
#   Member 34: 2.716615 kN
#   Member 33: 20.922376 kN
#   Member 21: -0.214021 kN
#   Member 26: 21.085136 kN
#   Member 42: -22.926360 kN
#   Member 41: -5.085514 kN
# --------------------------------------------------
# Generation 203: New Best Volume = 349.900832 cubic units
# Current Fixed Member Forces:
#   Member 34: -0.599572 kN
#   Member 33: 24.250959 kN
#   Member 21: -0.397760 kN
#   Member 26: 18.829386 kN
#   Member 42: -20.748256 kN
#   Member 41: -1.196690 kN
# --------------------------------------------------
# Generation 221: New Best Volume = 348.459929 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.469441 kN
#   Member 33: 22.871654 kN
#   Member 21: -0.397760 kN
#   Member 26: 18.829386 kN
#   Member 42: -20.748256 kN
#   Member 41: -1.196690 kN
# --------------------------------------------------
# Generation 222: New Best Volume = 348.319398 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.772626 kN
#   Member 33: 20.809881 kN
#   Member 21: 1.095823 kN
#   Member 26: 20.458101 kN
#   Member 42: -22.201948 kN
#   Member 41: -2.402281 kN
# --------------------------------------------------
# Generation 243: New Best Volume = 347.626514 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.836857 kN
#   Member 33: 19.491513 kN
#   Member 21: -2.320696 kN
#   Member 26: 19.322362 kN
#   Member 42: -21.458877 kN
#   Member 41: -3.217900 kN
# --------------------------------------------------
# Generation 244: New Best Volume = 345.328695 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.772626 kN
#   Member 33: 20.809881 kN
#   Member 21: 1.095823 kN
#   Member 26: 20.458101 kN
#   Member 42: -21.352179 kN
#   Member 41: 0.438633 kN
# --------------------------------------------------
# Generation 246: New Best Volume = 342.554277 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.163055 kN
#   Member 33: 19.808318 kN
#   Member 21: -0.031679 kN
#   Member 26: 18.652457 kN
#   Member 42: -21.352179 kN
#   Member 41: 0.559405 kN
# --------------------------------------------------
# Generation 289: New Best Volume = 342.417461 cubic units
# Current Fixed Member Forces:
#   Member 34: 2.241731 kN
#   Member 33: 19.808318 kN
#   Member 21: -0.768000 kN
#   Member 26: 19.688338 kN
#   Member 42: -21.352179 kN
#   Member 41: 0.559405 kN
# --------------------------------------------------
# Generation 293: New Best Volume = 342.190102 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.028673 kN
#   Member 33: 20.378974 kN
#   Member 21: -2.010263 kN
#   Member 26: 18.807889 kN
#   Member 42: -22.101594 kN
#   Member 41: -0.780425 kN
# --------------------------------------------------
# Generation 317: New Best Volume = 340.184129 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.028673 kN
#   Member 33: 20.378974 kN
#   Member 21: -2.010263 kN
#   Member 26: 19.061276 kN
#   Member 42: -20.751558 kN
#   Member 41: -0.780425 kN
# --------------------------------------------------
# Generation 362: New Best Volume = 339.472243 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.184185 kN
#   Member 33: 21.789599 kN
#   Member 21: 0.117871 kN
#   Member 26: 21.090293 kN
#   Member 42: -23.102457 kN
#   Member 41: -1.570901 kN
# --------------------------------------------------
# Generation 380: New Best Volume = 337.078336 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.184185 kN
#   Member 33: 21.789599 kN
#   Member 21: 0.117871 kN
#   Member 26: 21.090293 kN
#   Member 42: -22.316550 kN
#   Member 41: -1.510434 kN
# --------------------------------------------------
# Generation 394: New Best Volume = 336.796368 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.184185 kN
#   Member 33: 21.789599 kN
#   Member 21: 0.117871 kN
#   Member 26: 21.090293 kN
#   Member 42: -22.316550 kN
#   Member 41: -0.403031 kN
# --------------------------------------------------
# Generation 432: New Best Volume = 336.690383 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.002677 kN
#   Member 33: 21.196021 kN
#   Member 21: 0.494862 kN
#   Member 26: 19.719110 kN
#   Member 42: -21.416723 kN
#   Member 41: -0.513593 kN
# --------------------------------------------------
# Generation 433: New Best Volume = 334.246653 cubic units
# Current Fixed Member Forces:
#   Member 34: 1.680059 kN
#   Member 33: 21.300559 kN
#   Member 21: 0.117871 kN
#   Member 26: 21.090293 kN
#   Member 42: -21.581658 kN
#   Member 41: -1.428369 kN
# --------------------------------------------------
# Generation 454: New Best Volume = 333.324110 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.610943 kN
#   Member 33: 21.359394 kN
#   Member 21: -0.334443 kN
#   Member 26: 19.743137 kN
#   Member 42: -21.026156 kN
#   Member 41: -0.011230 kN
# --------------------------------------------------
# Generation 456: New Best Volume = 332.855938 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.030227 kN
#   Member 33: 21.282068 kN
#   Member 21: 0.331557 kN
#   Member 26: 20.012077 kN
#   Member 42: -21.391781 kN
#   Member 41: -0.054337 kN
# --------------------------------------------------
# Generation 461: New Best Volume = 332.585844 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.538610 kN
#   Member 33: 21.282068 kN
#   Member 21: -0.113577 kN
#   Member 26: 20.261605 kN
#   Member 42: -21.161750 kN
#   Member 41: -0.942018 kN
# --------------------------------------------------
# Generation 476: New Best Volume = 332.437163 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.538610 kN
#   Member 33: 21.282068 kN
#   Member 21: -0.113577 kN
#   Member 26: 20.261605 kN
#   Member 42: -21.161750 kN
#   Member 41: -0.267712 kN
# --------------------------------------------------
# Generation 479: New Best Volume = 332.215453 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.156564 kN
#   Member 33: 21.118846 kN
#   Member 21: -0.227098 kN
#   Member 26: 19.802693 kN
#   Member 42: -20.889312 kN
#   Member 41: -0.267547 kN
# --------------------------------------------------
# Generation 480: New Best Volume = 332.130688 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.538610 kN
#   Member 33: 21.282068 kN
#   Member 21: -0.113577 kN
#   Member 26: 20.261605 kN
#   Member 42: -21.007638 kN
#   Member 41: -0.643290 kN
# --------------------------------------------------
# Generation 485: New Best Volume = 331.522449 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.088891 kN
#   Member 33: 21.372821 kN
#   Member 21: -0.034284 kN
#   Member 26: 19.958384 kN
#   Member 42: -21.160256 kN
#   Member 41: -0.225720 kN
# --------------------------------------------------
# Generation 489: New Best Volume = 331.472072 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.088891 kN
#   Member 33: 21.355010 kN
#   Member 21: -0.034284 kN
#   Member 26: 19.958384 kN
#   Member 42: -21.160256 kN
#   Member 41: -0.225720 kN
# --------------------------------------------------
# Generation 492: New Best Volume = 331.140107 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.088891 kN
#   Member 33: 21.260413 kN
#   Member 21: 0.041087 kN
#   Member 26: 19.958384 kN
#   Member 42: -21.260413 kN
#   Member 41: 0.044338 kN
# --------------------------------------------------
# Generation 495: New Best Volume = 330.989688 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.024846 kN
#   Member 33: 21.393662 kN
#   Member 21: 0.010047 kN
#   Member 26: 20.026375 kN
#   Member 42: -21.234163 kN
#   Member 41: 0.030867 kN
# --------------------------------------------------
# Generation 497: New Best Volume = 330.713350 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.168414 kN
#   Member 33: 21.233907 kN
#   Member 21: 0.055820 kN
#   Member 26: 20.078238 kN
#   Member 42: -21.253175 kN
#   Member 41: -0.063837 kN
# --------------------------------------------------
# Generation 499: New Best Volume = 330.654909 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.098169 kN
#   Member 33: 21.274117 kN
#   Member 21: -0.004174 kN
#   Member 26: 19.999494 kN
#   Member 42: -21.232323 kN
#   Member 41: 0.023290 kN
# --------------------------------------------------
# Generation 500: New Best Volume = 330.463712 cubic units
# Current Fixed Member Forces:
#   Member 34: 0.003690 kN
#   Member 33: 21.270308 kN
#   Member 21: 0.033578 kN
#   Member 26: 20.049195 kN
#   Member 42: -21.256453 kN
#   Member 41: 0.005817 kN
# --------------------------------------------------
#
# --- Optimization Results ---
#
# Optimized Fixed Member Forces:
#   Member 34: 0.003690 kN
#   Member 33: 21.270308 kN
#   Member 21: 0.033578 kN
#   Member 26: 20.049195 kN
#   Member 42: -21.256453 kN
#   Member 41: 0.005817 kN
#
# Minimum Structure Volume Achieved: 330.463712 cubic units

# %% [markdown]
# ## Trying 4 cells

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
from matplotlib.colors import LinearSegmentedColormap
import random
import copy

# ------------------------- Configuration -------------------------

USE_SEED = False  # Set to False to disable fixed random seed

# New Configuration Options
SPECIFY_FIXED_MEMBERS = True  # Set to True to specify fixed members manually
SPECIFIED_FIXED_MEMBER_IDS = [44, 43, 48, 47, 31, 36, 56, 55]  # List of member IDs to fix

# Truss Configuration
COLUMNS = 9  # Number of columns of nodes
ROWS = 3     # Number of rows of nodes

# Load Nodes: {node_id: [Fx, Fy], ...}
# Nodes 3, 6, 9, 12, 15, 18, 21 have a load of [0, -10]
LOAD_NODES = {
    3: [0, -10],
    6: [0, -10],
    9: [0, -10],
    12: [0, -10],
    15: [0, -10],
    18: [0, -10],
    21: [0, -10],
    24: [0, -10],
    27: [0, -10]
}

# Support Nodes: {node_id: [Restrain_x (1 or 0), Restrain_y (1 or 0)], ...}
# Nodes 1 and 19 are supports restrained in x and y
SUPPORT_NODES = {
    1: [1, 1],
    25: [1, 1]
}

# ------------------------- Part 1: Truss Definition -------------------------

class Truss:
    def __init__(self, columns=COLUMNS, rows=ROWS, load_nodes=LOAD_NODES, support_nodes=SUPPORT_NODES):
        self.columns = columns
        self.rows = rows
        self.nodes = {}
        self.members = {}
        self.external_loads = load_nodes  # {node_id: [Fx, Fy], ...}
        self.support_nodes = support_nodes  # {node_id: [Restrain_x, Restrain_y], ...}
        self.support_reactions = {}  # Will be populated based on support_nodes
        self.fixed_member_ids = []  # To be set dynamically based on degree of indeterminacy
        self.degree_of_indeterminacy = 0
        self.direction_cosines_cache = {}
        self.initialize_truss()

    def initialize_truss(self):
        self.define_nodes()
        self.define_members()
        self.define_support_reactions()
        self.compute_degree_of_indeterminacy()

    def define_nodes(self):
        node_id = 1
        for x in range(self.columns):       # x=0 to x=COLUMNS-1
            for y in range(self.rows):      # y=0 to y=ROWS-1
                self.nodes[node_id] = (x, y)
                node_id += 1

    def add_member(self, start, end):
        if start not in self.nodes or end not in self.nodes:
            print(f"Skipping member ({start}, {end}) - Invalid node number.")
            return
        # Avoid duplicate members
        if not any(
            (start == existing_start and end == existing_end) or
            (start == existing_end and end == existing_start)
            for existing_start, existing_end in self.members.values()
        ):
            self.members[len(self.members) + 1] = (start, end)

    def define_members(self):
        # Add vertical members
        for x in range(self.columns):
            for y in range(self.rows - 1):
                node_start = x * self.rows + y + 1
                node_end = node_start + 1
                self.add_member(node_start, node_end)

        # Add horizontal members
        for x in range(self.columns - 1):
            for y in range(self.rows):
                node_start = x * self.rows + y + 1
                node_end = (x + 1) * self.rows + y + 1
                self.add_member(node_start, node_end)

        # Add diagonal members at special nodes
        for x in range(self.columns):
            for y in range(self.rows):
                # Identify special nodes (every second node in every second column)
                if x % 2 == 1 and y % 2 == 1:
                    current_node = x * self.rows + y + 1
                    # Top-right diagonal
                    if x < self.columns - 1 and y < self.rows - 1:
                        node_tr = (x + 1) * self.rows + y + 2
                        self.add_member(current_node, node_tr)
                    # Top-left diagonal
                    if x > 0 and y < self.rows - 1:
                        node_tl = (x - 1) * self.rows + y + 2
                        self.add_member(current_node, node_tl)
                    # Bottom-left diagonal
                    if x > 0 and y > 0:
                        node_bl = (x - 1) * self.rows + y
                        self.add_member(current_node, node_bl)
                    # Bottom-right diagonal
                    if x < self.columns - 1 and y > 0:
                        node_br = (x + 1) * self.rows + y
                        self.add_member(current_node, node_br)

    def find_node(self, x, y):
        for nid, coord in self.nodes.items():
            if coord == (x, y):
                return nid
        return None

    def define_support_reactions(self):
        # For each support node, define reactions based on restraints
        self.support_reactions = {}
        for node_id, restraints in self.support_nodes.items():
            restrain_x, restrain_y = restraints
            if restrain_x:
                self.support_reactions[f'R{node_id}x'] = None
            if restrain_y:
                self.support_reactions[f'R{node_id}y'] = None

    def compute_degree_of_indeterminacy(self):
        num_reactions = len(self.support_reactions)
        num_members = len(self.members)
        num_nodes = len(self.nodes)
        self.degree_of_indeterminacy = num_members + num_reactions - 2 * num_nodes

    def direction_cosines(self, start, end):
        key = tuple(sorted((start, end)))
        if key in self.direction_cosines_cache:
            return self.direction_cosines_cache[key]
        x1, y1 = self.nodes[start]
        x2, y2 = self.nodes[end]
        delta_x = x2 - x1
        delta_y = y2 - y1
        length = np.sqrt(delta_x**2 + delta_y**2)
        if length == 0:
            raise ValueError(f"Zero length member between nodes {start} and {end}.")
        cos_theta = delta_x / length
        sin_theta = delta_y / length
        self.direction_cosines_cache[key] = (cos_theta, sin_theta)
        return cos_theta, sin_theta

# ------------------------- Part 2: Genetic Algorithm for Minimum Truss Volume -------------------------

class GeneticAlgorithmOptimizer:
    def __init__(self, truss, seed_fixed_member_ids, seed_fixed_forces,
                 material_stress=1, population_size=200, generations=200,
                 tournament_size=3, crossover_rate=0.8, mutation_rate=0.5, mutation_amount=10, elitism=True):
        self.truss = truss
        self.seed_fixed_member_ids = seed_fixed_member_ids
        self.seed_fixed_forces = seed_fixed_forces
        self.material_stress = material_stress

        # Genetic Algorithm Parameters
        self.POPULATION_SIZE = population_size
        self.GENERATIONS = generations
        self.TOURNAMENT_SIZE = tournament_size
        self.CROSSOVER_RATE = crossover_rate
        self.MUTATION_RATE = mutation_rate
        self.MUTATION_AMOUNT = mutation_amount
        self.elitism = elitism

        # Define gene bounds (-50 to 50)
        self.gene_bounds = [(-50, 50) for _ in self.seed_fixed_forces]

        # Create mappings
        self.fixed_member_indices = [m - 1 for m in self.seed_fixed_member_ids]
        self.unknown_member_indices = [
            i for i in range(len(truss.members)) if i not in self.fixed_member_indices
        ]
        self.num_reactions = len(truss.support_reactions)
        self.num_members = len(truss.members)
        self.num_unknowns_ga = len(self.unknown_member_indices) + self.num_reactions

        # Mapping from member index to unknown index
        self.member_index_to_unknown = {
            i: idx for idx, i in enumerate(self.unknown_member_indices)
        }

        # Mapping for reaction indices
        self.reaction_indices = {}
        for idx, reaction in enumerate(self.truss.support_reactions):
            self.reaction_indices[reaction] = len(self.unknown_member_indices) + idx

    def initialize_population(self):
        population = []
        for _ in range(self.POPULATION_SIZE):
            individual = [
                random.uniform(low, high) for (low, high) in self.gene_bounds
            ]
            population.append(individual)
        return population

    def compute_total_volume(self, current_fixed_member_forces):
        A_ga, B_ga = self.setup_equilibrium(current_fixed_member_forces)
        try:
            F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
            equilibrium_satisfied_ga = True
        except np.linalg.LinAlgError:
            F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)
            equilibrium_satisfied_ga = False

        # Check equilibrium
        B_calculated = np.dot(A_ga, F_unknowns_ga)
        difference = B_calculated - B_ga
        tolerance = 1e-5  # Adjust tolerance as needed
        if np.any(np.abs(difference) > tolerance):
            # Equilibrium not satisfied, return a large fitness value
            return 1e10  # Large penalty
        else:
            # Reconstruct full member forces
            F_full_ga = np.zeros(self.num_members)
            for member_index in self.unknown_member_indices:
                unknown_idx = self.member_index_to_unknown[member_index]
                F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
            for i, m_id in enumerate(self.seed_fixed_member_ids):
                F_full_ga[m_id - 1] = current_fixed_member_forces[m_id]

            # Calculate total volume
            total_volume = 0.0
            for m_id, (start, end) in self.truss.members.items():
                x1, y1 = self.truss.nodes[start]
                x2, y2 = self.truss.nodes[end]
                length = np.sqrt((x2 - x1)**2 + (y2 - y1)**2)
                force_magnitude = abs(F_full_ga[m_id - 1])
                cross_sectional_area = force_magnitude / self.material_stress
                volume = cross_sectional_area * length
                total_volume += volume

            return total_volume

    def setup_equilibrium(self, current_fixed_member_forces):
        num_members = self.num_members
        num_reactions = self.num_reactions
        num_nodes = len(self.truss.nodes)
        equations_per_node = 2
        total_equations = num_nodes * equations_per_node
        total_unknowns = self.num_unknowns_ga

        A_ga = np.zeros((total_equations, total_unknowns))
        B_ga = np.zeros(total_equations)

        # Map reactions to indices
        reaction_indices = self.reaction_indices

        for node in self.truss.nodes:
            eq_x = (node - 1) * 2
            eq_y = eq_x + 1

            # Assign external loads
            load = self.truss.external_loads.get(node, [0, 0])
            B_ga[eq_x] += load[0]
            B_ga[eq_y] += load[1]

            # Iterate through connected members
            for m_id, (start, end) in self.truss.members.items():
                member_index = m_id - 1
                if node == start or node == end:
                    other = end if node == start else start
                    cos_theta, sin_theta = self.truss.direction_cosines(node, other)
                    coef_x = cos_theta if node == start else -cos_theta
                    coef_y = sin_theta if node == start else -sin_theta

                    if m_id in current_fixed_member_forces:
                        fixed_force = current_fixed_member_forces[m_id]
                        B_ga[eq_x] -= coef_x * fixed_force
                        B_ga[eq_y] -= coef_y * fixed_force
                    else:
                        if member_index in self.member_index_to_unknown:
                            unknown_idx = self.member_index_to_unknown[member_index]
                            A_ga[eq_x, unknown_idx] += coef_x
                            A_ga[eq_y, unknown_idx] += coef_y

            # Assign support reactions
            if node in self.truss.support_nodes:
                restraints = self.truss.support_nodes[node]
                restrain_x, restrain_y = restraints
                if restrain_x:
                    reaction_name = f'R{node}x'
                    A_ga[eq_x, reaction_indices[reaction_name]] -= 1
                if restrain_y:
                    reaction_name = f'R{node}y'
                    A_ga[eq_y, reaction_indices[reaction_name]] -= 1

        return A_ga, B_ga

    def fitness(self, individual):
        current_fixed_member_forces = {
            m: individual[i] for i, m in enumerate(self.seed_fixed_member_ids)
        }
        total_vol = self.compute_total_volume(current_fixed_member_forces)
        return total_vol  # Objective: minimize total volume

    def tournament_selection(self, population, scores):
        selected = []
        for _ in range(self.POPULATION_SIZE):
            aspirants = random.sample(range(len(population)), self.TOURNAMENT_SIZE)
            aspirant_scores = [scores[i] for i in aspirants]
            winner = aspirants[np.argmin(aspirant_scores)]
            selected.append(copy.deepcopy(population[winner]))
        return selected

    def mutate(self, individual, generation):
        # Adaptive mutation amount: decreases over generations
        adaptive_mutation_amount = self.MUTATION_AMOUNT * (1 - generation / self.GENERATIONS)
        for i in range(len(individual)):
            if random.random() < self.MUTATION_RATE:
                mutation = random.uniform(-adaptive_mutation_amount, adaptive_mutation_amount)
                individual[i] += mutation
                # Clamp the gene within bounds
                low, high = self.gene_bounds[i]
                individual[i] = max(low, min(individual[i], high))
        return individual

    def run(self):
        population = self.initialize_population()
        best_volume = float('inf')
        best_individual = None

        for gen in range(1, self.GENERATIONS + 1):
            # Evaluate fitness
            scores = [self.fitness(ind) for ind in population]
            # Find the best individual in current generation
            min_score = min(scores)
            min_index = scores.index(min_score)
            current_best_individual = population[min_index]
            current_best_volume = min_score

            # Update global best
            if current_best_volume < best_volume:
                best_volume = current_best_volume
                best_individual = copy.deepcopy(current_best_individual)
                print(f"Generation {gen}: New Best Volume = {best_volume:.6f} cubic units")
                print("Current Fixed Member Forces:")
                for i, m in enumerate(self.seed_fixed_member_ids):
                    print(f"  Member {m}: {best_individual[i]:.6f} kN")
                print("-" * 50)

            # Selection
            selected = self.tournament_selection(population, scores)

            # Crossover and Mutation
            next_generation = []

            # Elitism: carry over the best individual
            if self.elitism:
                next_generation.append(best_individual)

            while len(next_generation) < self.POPULATION_SIZE:
                parent1 = random.choice(selected)
                parent2 = random.choice(selected)
                child1, child2 = self.crossover(parent1, parent2)
                child1 = self.mutate(child1, gen)
                child2 = self.mutate(child2, gen)
                next_generation.extend([child1, child2])

            population = next_generation[:self.POPULATION_SIZE]

        return best_individual, best_volume

    def crossover(self, parent1, parent2):
        if random.random() < self.CROSSOVER_RATE:
            point = random.randint(1, len(parent1) - 1)
            child1 = parent1[:point] + parent2[point:]
            child2 = parent2[:point] + parent1[point:]
            return child1, child2
        return copy.deepcopy(parent1), copy.deepcopy(parent2)

# ------------------------- Part 3: Visualization of Truss -------------------------

def visualize_truss(truss, fixed_member_forces, title="Truss Structure"):
    """
    Visualize the truss structure with member forces and Member IDs.
    """
    # Setup equilibrium with given fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(fixed_member_forces.keys()),
        seed_fixed_forces=fixed_member_forces,
        material_stress=1  # Assuming material_stress is 1 for consistency
    )

    A_ga, B_ga = optimizer.setup_equilibrium(fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = fixed_member_forces[m_id]

    # Plot the Truss
    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Define colors for different member statuses
    tension_color = 'blue'
    compression_color = 'red'
    zero_color = 'gray'
    fixed_color = 'green'

    # Plot each member
    for m_id, (start, end) in truss.members.items():
        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        force = F_full_ga[m_id - 1]

        # Determine color based on force
        if m_id in optimizer.seed_fixed_member_ids:
            color = fixed_color
            linewidth = 2
        else:
            # Swap the interpretation: Positive = Compression, Negative = Tension
            if force > 0:
                color = compression_color  # Previously tension_color
                linewidth = 2
            elif force < 0:
                color = tension_color  # Previously compression_color
                linewidth = 2
            else:
                color = zero_color
                linewidth = 1

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=linewidth)

        # Annotate the force value at the midpoint
        x_mid = (x_start + x_end) / 2
        y_mid = (y_start + y_end) / 2
        if force != 0:
            plt.text(x_mid, y_mid, f"{force:.1f}kN",
                     color='black', fontsize=8, ha='center', va='center')

        # Annotate the Member ID slightly offset from the midpoint
        offset = 0.1  # Adjust as needed for clarity
        plt.text(x_mid + offset, y_mid + offset, f"ID:{m_id}",
                 color='purple', fontsize=8, ha='center', va='center')

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Plot supports
    support_plotted = False
    for node_id, restraints in truss.support_nodes.items():
        x, y = truss.nodes[node_id]
        plt.plot(x, y, marker='^', markersize=10, markerfacecolor='black',
                 label='Support' if not support_plotted else "")
        support_plotted = True

    # Create custom legend
    tension_patch = mpatches.Patch(color=tension_color, label='Tension')  # Now correctly represents negative forces
    compression_patch = mpatches.Patch(color=compression_color, label='Compression')  # Now correctly represents positive forces
    zero_patch = mpatches.Patch(color=zero_color, label='Zero-force')
    fixed_patch = mpatches.Patch(color=fixed_color, label='Fixed Force')
    handles = [tension_patch, compression_patch, zero_patch, fixed_patch]
    if support_plotted:
        pin_patch = Line2D([0], [0], marker='^', color='w', label='Support',
                           markerfacecolor='black', markersize=10)
        handles.append(pin_patch)
    plt.legend(handles=handles, loc='upper right')

    plt.grid(True)
    plt.show()

def plot_cross_section_colored_truss(truss, fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections"):
    """
    Plot the truss with cross-sectional areas colored based on normalized values.
    """
    # Setup equilibrium with given fixed forces
    num_members = len(truss.members)
    num_reactions = len(truss.support_reactions)
    num_nodes = len(truss.nodes)
    equations_per_node = 2
    total_equations = num_nodes * equations_per_node

    # Setup Genetic Algorithm specific mappings
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=list(fixed_member_forces.keys()),
        seed_fixed_forces=fixed_member_forces,
        material_stress=material_stress
    )

    A_ga, B_ga = optimizer.setup_equilibrium(fixed_member_forces)
    try:
        F_unknowns_ga = np.linalg.solve(A_ga, B_ga)
    except np.linalg.LinAlgError:
        F_unknowns_ga, residuals, rank, s = np.linalg.lstsq(A_ga, B_ga, rcond=None)

    # Reconstruct full member forces
    F_full_ga = np.zeros(num_members)
    for member_index in optimizer.unknown_member_indices:
        unknown_idx = optimizer.member_index_to_unknown[member_index]
        F_full_ga[member_index] = F_unknowns_ga[unknown_idx]
    for i, m_id in enumerate(optimizer.seed_fixed_member_ids):
        F_full_ga[m_id - 1] = fixed_member_forces[m_id]

    # Calculate cross-sectional areas and exclude members with zero force or force <1kN
    cross_sections = {}
    for m_id, force in zip(range(1, num_members + 1), F_full_ga):
        if force != 0 and abs(force) >= 1:
            cross_sections[m_id] = abs(force) / material_stress

    if not cross_sections:
        print("No members with non-zero force >= 1kN to plot.")
        return

    # Normalize cross-sectional areas for color mapping
    min_cs = min(cross_sections.values())
    max_cs = max(cross_sections.values())
    if max_cs != min_cs:
        normalized_cs = {m_id: (cs - min_cs) / (max_cs - min_cs) for m_id, cs in cross_sections.items()}
    else:
        normalized_cs = {m_id: 0.5 for m_id in cross_sections}  # All same color

    # Create a custom "dark rainbow" colormap reversed: dark blue to red
    dark_rainbow = LinearSegmentedColormap.from_list('dark_rainbow', ['darkblue', 'lightblue', 'green', 'yellow', 'orange', 'red'])

    plt.figure(figsize=(14, 6))
    ax = plt.gca()
    ax.set_aspect('equal')
    plt.title(title)
    plt.xlabel('X-coordinate (m)')
    plt.ylabel('Y-coordinate (m)')

    # Plot each member with color based on normalized cross-section
    for m_id, (start, end) in truss.members.items():
        if m_id not in cross_sections:
            continue  # Skip members with zero force or force <1kN

        x_start, y_start = truss.nodes[start]
        x_end, y_end = truss.nodes[end]
        normalized_value = normalized_cs[m_id]
        color = dark_rainbow(normalized_value)

        # Plot the member
        plt.plot([x_start, x_end], [y_start, y_end], color=color, linewidth=2)

        # Annotate the Member ID slightly offset from the midpoint
        x_mid = (x_start + x_end) / 2
        y_mid = (y_start + y_end) / 2
        offset = 0.1  # Adjust as needed for clarity
        plt.text(x_mid + offset, y_mid + offset, f"ID:{m_id}",
                 color='purple', fontsize=8, ha='center', va='center')

    # Plot the nodes
    for node, (x, y) in truss.nodes.items():
        plt.plot(x, y, 'ko')  # Black circles for nodes
        plt.text(x, y + 0.05, f"{node}", fontsize=9, ha='center')

    # Plot supports
    support_plotted = False
    for node_id, restraints in truss.support_nodes.items():
        x, y = truss.nodes[node_id]
        plt.plot(x, y, marker='^', markersize=10, markerfacecolor='black',
                 label='Support' if not support_plotted else "")
        support_plotted = True

    # Create a colorbar
    sm = plt.cm.ScalarMappable(cmap=dark_rainbow, norm=plt.Normalize(vmin=min_cs, vmax=max_cs))
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=ax, shrink=0.6)
    cbar.set_label('Cross-Sectional Area (normalized)')

    # Create custom legend for supports
    handles = []
    tension_patch = mpatches.Patch(color='blue', label='Tension')
    compression_patch = mpatches.Patch(color='red', label='Compression')
    zero_patch = mpatches.Patch(color='gray', label='Zero-force')
    fixed_patch = mpatches.Patch(color='green', label='Fixed Force')
    handles.extend([tension_patch, compression_patch, zero_patch, fixed_patch])
    if support_plotted:
        pin_patch = Line2D([0], [0], marker='^', color='w', label='Support',
                           markerfacecolor='black', markersize=10)
        handles.append(pin_patch)
    plt.legend(handles=handles, loc='upper right')

    plt.grid(True)
    plt.show()

# ------------------------- Utility Function -------------------------

def select_random_fixed_members(truss, N):
    total_members = len(truss.members)
    if N > total_members:
        raise ValueError(f"Cannot select {N} members as there are only {total_members} members.")
    fixed_member_ids = random.sample(range(1, total_members + 1), N)
    return fixed_member_ids

# ------------------------- Main Execution -------------------------

if __name__ == "__main__":
    # Set random seeds for reproducibility (optional)
    if USE_SEED:
        random.seed(42)
        np.random.seed(42)
        print("Random seeds are set for reproducibility.\n")
    else:
        print("Random seeds are not set. Results may vary with each run.\n")

    # Initialize the truss
    truss = Truss()

    # Compute degree of indeterminacy
    truss.compute_degree_of_indeterminacy()
    print(f"Degree of Indeterminacy: {truss.degree_of_indeterminacy}\n")

    # Determine fixed members based on user configuration
    N = truss.degree_of_indeterminacy
    if SPECIFY_FIXED_MEMBERS:
        if len(SPECIFIED_FIXED_MEMBER_IDS) != N:
            print(f"Error: Number of specified fixed members ({len(SPECIFIED_FIXED_MEMBER_IDS)}) does not match the degree of indeterminacy ({N}).")
            exit(1)
        fixed_member_ids = SPECIFIED_FIXED_MEMBER_IDS
    else:
        fixed_member_ids = select_random_fixed_members(truss, N)

    # Assign the fixed_member_ids to the truss
    truss.fixed_member_ids = fixed_member_ids

    # Generate random initial forces for the fixed members between -50 and 50
    seed_fixed_forces = {m_id: random.uniform(-50, 50) for m_id in fixed_member_ids}

    # Print selected fixed members and their initial random forces
    print("--- Genetic Algorithm Optimization ---\n")
    print(f"Selected Fixed Members (Total {N}):")
    for m_id, force in seed_fixed_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print("\nVisualizing Initial Truss Structure...\n")

    # Visualize the initial truss before optimization
    visualize_truss(truss, seed_fixed_forces, title="Initial Truss Structure")

    print("\nStarting Genetic Algorithm...\n")

    # Initialize and run the genetic algorithm optimizer
    optimizer = GeneticAlgorithmOptimizer(
        truss=truss,
        seed_fixed_member_ids=fixed_member_ids,
        seed_fixed_forces=seed_fixed_forces,
        material_stress=1,          # Adjust based on material properties
        population_size=200,        # Increased population size for diversity
        generations=500,            # Increased number of generations
        tournament_size=3,          # Number of individuals competing in tournament selection
        crossover_rate=0.8,         # Probability of crossover
        mutation_rate=0.5,          # Increased mutation rate
        mutation_amount=20,         # Increased mutation amount
        elitism=True                # Use elitism to preserve the best individual
    )

    best_individual, best_volume = optimizer.run()

    # Map the best individual to fixed member forces
    optimized_fixed_member_forces = {m_id: best_individual[i] for i, m_id in enumerate(fixed_member_ids)}

    # Print optimization results
    print("\n--- Optimization Results ---\n")
    print("Optimized Fixed Member Forces:")
    for m_id, force in optimized_fixed_member_forces.items():
        print(f"  Member {m_id}: {force:.6f} kN")
    print(f"\nMinimum Structure Volume Achieved: {best_volume:.6f} cubic units\n")

    # Visualize the optimized truss
    visualize_truss(truss, optimized_fixed_member_forces, title="Optimized Truss Structure with Minimized Volume")

    # Plot the cross-section normalized truss
    plot_cross_section_colored_truss(truss, optimized_fixed_member_forces, material_stress=1, title="Optimized Truss with Normalized Cross Sections")
# Out:
# Random seeds are not set. Results may vary with each run.
#
# Degree of Indeterminacy: 8
#
# --- Genetic Algorithm Optimization ---
#
# Selected Fixed Members (Total 8):
#   Member 44: 49.948737 kN
#   Member 43: 29.632484 kN
#   Member 48: -14.986809 kN
#   Member 47: -14.132376 kN
#   Member 31: 33.973225 kN
#   Member 36: 12.555499 kN
#   Member 56: 28.963306 kN
#   Member 55: 24.585432 kN
#
# Visualizing Initial Truss Structure...
# Starting Genetic Algorithm...
#
# Generation 1: New Best Volume = 931.195346 cubic units
# Current Fixed Member Forces:
#   Member 44: -1.658720 kN
#   Member 43: 32.036319 kN
#   Member 48: 1.878393 kN
#   Member 47: -11.406438 kN
#   Member 31: -1.307746 kN
#   Member 36: 30.340404 kN
#   Member 56: -27.171574 kN
#   Member 55: -3.462779 kN
# --------------------------------------------------
# Generation 2: New Best Volume = 749.923572 cubic units
# Current Fixed Member Forces:
#   Member 44: -1.625715 kN
#   Member 43: 40.440872 kN
#   Member 48: 7.720702 kN
#   Member 47: 0.791287 kN
#   Member 31: -10.198438 kN
#   Member 36: 35.528311 kN
#   Member 56: -34.503620 kN
#   Member 55: -5.335948 kN
# --------------------------------------------------
# Generation 7: New Best Volume = 743.705982 cubic units
# Current Fixed Member Forces:
#   Member 44: 7.548476 kN
#   Member 43: 26.811215 kN
#   Member 48: 15.827546 kN
#   Member 47: 2.470911 kN
#   Member 31: -1.805524 kN
#   Member 36: 34.898364 kN
#   Member 56: -23.006674 kN
#   Member 55: 0.864184 kN
# --------------------------------------------------
# Generation 17: New Best Volume = 731.975135 cubic units
# Current Fixed Member Forces:
#   Member 44: 10.385515 kN
#   Member 43: 25.964516 kN
#   Member 48: 12.203902 kN
#   Member 47: 9.479078 kN
#   Member 31: 3.211139 kN
#   Member 36: 33.359628 kN
#   Member 56: -36.402759 kN
#   Member 55: 4.931335 kN
# --------------------------------------------------
# Generation 18: New Best Volume = 690.184081 cubic units
# Current Fixed Member Forces:
#   Member 44: 7.548476 kN
#   Member 43: 26.811215 kN
#   Member 48: 15.827546 kN
#   Member 47: 2.470911 kN
#   Member 31: -1.805524 kN
#   Member 36: 31.041640 kN
#   Member 56: -34.436626 kN
#   Member 55: 0.864184 kN
# --------------------------------------------------
# Generation 22: New Best Volume = 673.347748 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.715303 kN
#   Member 43: 40.386202 kN
#   Member 48: 6.028138 kN
#   Member 47: 5.814735 kN
#   Member 31: -3.768741 kN
#   Member 36: 35.076266 kN
#   Member 56: -33.351907 kN
#   Member 55: -3.005571 kN
# --------------------------------------------------
# Generation 32: New Best Volume = 672.984044 cubic units
# Current Fixed Member Forces:
#   Member 44: -3.930906 kN
#   Member 43: 33.664719 kN
#   Member 48: 21.578508 kN
#   Member 47: 5.814735 kN
#   Member 31: -5.391730 kN
#   Member 36: 32.104533 kN
#   Member 56: -33.351907 kN
#   Member 55: -3.940155 kN
# --------------------------------------------------
# Generation 51: New Best Volume = 664.930765 cubic units
# Current Fixed Member Forces:
#   Member 44: 3.032971 kN
#   Member 43: 34.346257 kN
#   Member 48: 9.204976 kN
#   Member 47: 8.957660 kN
#   Member 31: -1.864380 kN
#   Member 36: 36.660926 kN
#   Member 56: -42.662460 kN
#   Member 55: -0.377759 kN
# --------------------------------------------------
# Generation 61: New Best Volume = 657.225562 cubic units
# Current Fixed Member Forces:
#   Member 44: 8.364609 kN
#   Member 43: 28.698518 kN
#   Member 48: 14.602600 kN
#   Member 47: 3.984557 kN
#   Member 31: -3.631687 kN
#   Member 36: 38.158663 kN
#   Member 56: -35.662407 kN
#   Member 55: -2.606812 kN
# --------------------------------------------------
# Generation 102: New Best Volume = 645.359892 cubic units
# Current Fixed Member Forces:
#   Member 44: 4.784369 kN
#   Member 43: 32.563104 kN
#   Member 48: 14.602600 kN
#   Member 47: 3.984557 kN
#   Member 31: -3.631687 kN
#   Member 36: 38.158663 kN
#   Member 56: -35.662407 kN
#   Member 55: -2.606812 kN
# --------------------------------------------------
# Generation 214: New Best Volume = 645.089737 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.647746 kN
#   Member 43: 32.563104 kN
#   Member 48: 20.975587 kN
#   Member 47: 1.947043 kN
#   Member 31: -3.631687 kN
#   Member 36: 38.158663 kN
#   Member 56: -35.662407 kN
#   Member 55: -2.606812 kN
# --------------------------------------------------
# Generation 250: New Best Volume = 634.038348 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.647746 kN
#   Member 43: 32.563104 kN
#   Member 48: 20.975587 kN
#   Member 47: 1.947043 kN
#   Member 31: -0.568185 kN
#   Member 36: 37.570706 kN
#   Member 56: -35.662407 kN
#   Member 55: 0.333847 kN
# --------------------------------------------------
# Generation 298: New Best Volume = 630.615884 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.647746 kN
#   Member 43: 36.399306 kN
#   Member 48: 16.763303 kN
#   Member 47: 3.572875 kN
#   Member 31: -0.568185 kN
#   Member 36: 37.570706 kN
#   Member 56: -35.662407 kN
#   Member 55: -1.754501 kN
# --------------------------------------------------
# Generation 349: New Best Volume = 630.341993 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.363534 kN
#   Member 43: 36.399306 kN
#   Member 48: 15.996056 kN
#   Member 47: 5.964775 kN
#   Member 31: -4.391027 kN
#   Member 36: 34.976942 kN
#   Member 56: -35.310546 kN
#   Member 55: 0.433901 kN
# --------------------------------------------------
# Generation 350: New Best Volume = 629.651831 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.647746 kN
#   Member 43: 37.161996 kN
#   Member 48: 16.763303 kN
#   Member 47: 3.572875 kN
#   Member 31: -1.358567 kN
#   Member 36: 37.570706 kN
#   Member 56: -35.662407 kN
#   Member 55: 0.650966 kN
# --------------------------------------------------
# Generation 352: New Best Volume = 627.523004 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.647746 kN
#   Member 43: 33.696849 kN
#   Member 48: 16.763303 kN
#   Member 47: 4.950919 kN
#   Member 31: -1.194572 kN
#   Member 36: 37.570706 kN
#   Member 56: -33.792242 kN
#   Member 55: 0.650966 kN
# --------------------------------------------------
# Generation 354: New Best Volume = 626.408417 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.408924 kN
#   Member 43: 35.474844 kN
#   Member 48: 18.693802 kN
#   Member 47: 4.467318 kN
#   Member 31: -1.110844 kN
#   Member 36: 36.629037 kN
#   Member 56: -33.793899 kN
#   Member 55: -0.359434 kN
# --------------------------------------------------
# Generation 381: New Best Volume = 622.999265 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.408924 kN
#   Member 43: 35.474844 kN
#   Member 48: 18.693802 kN
#   Member 47: 4.467318 kN
#   Member 31: -2.481328 kN
#   Member 36: 36.629037 kN
#   Member 56: -33.793899 kN
#   Member 55: -0.359434 kN
# --------------------------------------------------
# Generation 402: New Best Volume = 622.255346 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.135387 kN
#   Member 43: 35.422605 kN
#   Member 48: 18.142763 kN
#   Member 47: 4.976382 kN
#   Member 31: -0.481994 kN
#   Member 36: 38.802061 kN
#   Member 56: -35.714244 kN
#   Member 55: -0.235828 kN
# --------------------------------------------------
# Generation 403: New Best Volume = 621.571115 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.196039 kN
#   Member 43: 34.788869 kN
#   Member 48: 18.693802 kN
#   Member 47: 4.130559 kN
#   Member 31: -2.481328 kN
#   Member 36: 36.702443 kN
#   Member 56: -33.793899 kN
#   Member 55: -0.359434 kN
# --------------------------------------------------
# Generation 415: New Best Volume = 621.468670 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.159820 kN
#   Member 43: 34.788869 kN
#   Member 48: 18.693802 kN
#   Member 47: 4.130559 kN
#   Member 31: -2.752895 kN
#   Member 36: 35.790644 kN
#   Member 56: -33.495309 kN
#   Member 55: -0.359434 kN
# --------------------------------------------------
# Generation 430: New Best Volume = 620.756027 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.159820 kN
#   Member 43: 34.740217 kN
#   Member 48: 18.693802 kN
#   Member 47: 4.130559 kN
#   Member 31: -3.310444 kN
#   Member 36: 35.790644 kN
#   Member 56: -33.495309 kN
#   Member 55: 0.107476 kN
# --------------------------------------------------
# Generation 433: New Best Volume = 620.430051 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.001731 kN
#   Member 43: 34.949068 kN
#   Member 48: 17.780175 kN
#   Member 47: 5.239098 kN
#   Member 31: -2.523515 kN
#   Member 36: 37.404488 kN
#   Member 56: -34.714353 kN
#   Member 55: 0.126067 kN
# --------------------------------------------------
# Generation 434: New Best Volume = 620.361469 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.001731 kN
#   Member 43: 34.949068 kN
#   Member 48: 17.780175 kN
#   Member 47: 6.564147 kN
#   Member 31: -0.185364 kN
#   Member 36: 37.404488 kN
#   Member 56: -34.714353 kN
#   Member 55: 0.126067 kN
# --------------------------------------------------
# Generation 457: New Best Volume = 620.316182 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.033391 kN
#   Member 43: 34.008495 kN
#   Member 48: 18.277443 kN
#   Member 47: 6.088077 kN
#   Member 31: -1.643918 kN
#   Member 36: 37.211405 kN
#   Member 56: -35.043492 kN
#   Member 55: 0.078397 kN
# --------------------------------------------------
# Generation 465: New Best Volume = 620.169273 cubic units
# Current Fixed Member Forces:
#   Member 44: -0.033391 kN
#   Member 43: 34.008495 kN
#   Member 48: 17.436782 kN
#   Member 47: 6.088077 kN
#   Member 31: -1.643918 kN
#   Member 36: 37.211405 kN
#   Member 56: -35.043492 kN
#   Member 55: -0.026456 kN
# --------------------------------------------------
# Generation 481: New Best Volume = 620.119757 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.040934 kN
#   Member 43: 34.013980 kN
#   Member 48: 18.615188 kN
#   Member 47: 5.687781 kN
#   Member 31: -0.638833 kN
#   Member 36: 36.982055 kN
#   Member 56: -34.959489 kN
#   Member 55: -0.001406 kN
# --------------------------------------------------
# Generation 483: New Best Volume = 620.106204 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.011092 kN
#   Member 43: 34.106175 kN
#   Member 48: 18.065931 kN
#   Member 47: 5.644507 kN
#   Member 31: -1.788566 kN
#   Member 36: 37.334658 kN
#   Member 56: -33.971040 kN
#   Member 55: -0.026456 kN
# --------------------------------------------------
# Generation 484: New Best Volume = 620.098249 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.027312 kN
#   Member 43: 33.320616 kN
#   Member 48: 17.793277 kN
#   Member 47: 6.565424 kN
#   Member 31: -2.959480 kN
#   Member 36: 36.936927 kN
#   Member 56: -34.807513 kN
#   Member 55: 0.007424 kN
# --------------------------------------------------
# Generation 486: New Best Volume = 620.045956 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.000733 kN
#   Member 43: 33.927703 kN
#   Member 48: 17.832365 kN
#   Member 47: 5.084761 kN
#   Member 31: -0.275204 kN
#   Member 36: 38.096602 kN
#   Member 56: -34.959469 kN
#   Member 55: 0.015515 kN
# --------------------------------------------------
# Generation 490: New Best Volume = 620.043385 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.013933 kN
#   Member 43: 33.942396 kN
#   Member 48: 17.976012 kN
#   Member 47: 5.623340 kN
#   Member 31: -1.283991 kN
#   Member 36: 36.801700 kN
#   Member 56: -33.855673 kN
#   Member 55: -0.001406 kN
# --------------------------------------------------
# Generation 491: New Best Volume = 620.023071 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.000733 kN
#   Member 43: 33.675612 kN
#   Member 48: 18.104416 kN
#   Member 47: 5.236841 kN
#   Member 31: -0.031266 kN
#   Member 36: 37.066864 kN
#   Member 56: -34.441864 kN
#   Member 55: 0.007424 kN
# --------------------------------------------------
# Generation 495: New Best Volume = 620.011050 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.000733 kN
#   Member 43: 33.871242 kN
#   Member 48: 19.024823 kN
#   Member 47: 5.449389 kN
#   Member 31: -1.304327 kN
#   Member 36: 36.684109 kN
#   Member 56: -34.645160 kN
#   Member 55: -0.003174 kN
# --------------------------------------------------
# Generation 500: New Best Volume = 620.006984 cubic units
# Current Fixed Member Forces:
#   Member 44: 0.000733 kN
#   Member 43: 34.028914 kN
#   Member 48: 17.149264 kN
#   Member 47: 5.434696 kN
#   Member 31: -0.373925 kN
#   Member 36: 38.269681 kN
#   Member 56: -34.368196 kN
#   Member 55: 0.001736 kN
# --------------------------------------------------
#
# --- Optimization Results ---
#
# Optimized Fixed Member Forces:
#   Member 44: 0.000733 kN
#   Member 43: 34.028914 kN
#   Member 48: 17.149264 kN
#   Member 47: 5.434696 kN
#   Member 31: -0.373925 kN
#   Member 36: 38.269681 kN
#   Member 56: -34.368196 kN
#   Member 55: 0.001736 kN
#
# Minimum Structure Volume Achieved: 620.006984 cubic units
